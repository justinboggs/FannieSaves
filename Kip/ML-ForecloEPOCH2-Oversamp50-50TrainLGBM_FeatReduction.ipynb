# %% [markdown]
# # ML Foreclosure Binary Classification - EPOCH 2 data
#
#     target = zeroBalCode (set to object dtype)
#     Binary classification sets zeroBalCode to either "0" or "1" for the 7 possible outcomes
#
#     "0" = "Loan Success"
#         * 01 = Prepaid or Matured
#
#     "1" =  "Loan Failure" - Most likely loss of money (but not necessarily) one of below conditions:
#         * 02 = Third Party Sale
#         * 03 = Short Sale
#         * 06 = Repurchased
#         * 09 = Deed-in-Lieu,REO
#         * 15 = Note Sale
#         * 16 = Reperforming Loan Sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#!pip install pycaret
from imblearn.over_sampling import RandomOverSampler
from pycaret.classification import *
#from pycaret.regression import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Importing the data - only use *.ML.csv files!!!
# If you have *.MLReady.csv then [click here](#MLReady)

# %%
df=pd.read_csv("data/FM_Acq_Perf_FMAC_EPOCH2_ML.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            id  origChannel  origIntRate  origUPB  \
# 0     1133339       1133339  100209956357            2        5.125   348000
# 1     1133340       1133340  100392775700            3        4.625   195000
# 2     1133341       1133341  100621428854            2        4.875   342000
# 3     1133342       1133342  100720959726            1        5.375    93000
# 4     1133343       1133343  100783704799            1        4.875   182000
#
#      origDate firstPmtDate  origLTV  numBorrowers  ...  fmacRateMin  \
# 0  2009-02-01   2009-04-01     87.0           1.0  ...         5.04
# 1  2009-02-01   2009-04-01     52.0           2.0  ...         5.04
# 2  2009-02-01   2009-04-01     80.0           1.0  ...         5.04
# 3  2009-02-01   2009-05-01     70.0           1.0  ...         5.04
# 4  2009-02-01   2009-04-01     76.0           2.0  ...         5.04
#
#    fmacRateAvg  fmacRateVolatility  fredRate  rateDiffAbove  rateDiffBelow  \
# 0         5.13            0.041667      2.87         -0.125         -0.085
# 1         5.13            0.041667      2.87         -0.625          0.415
# 2         5.13            0.041667      2.87         -0.375          0.165
# 3         5.13            0.041667      2.87          0.125         -0.335
# 4         5.13            0.041667      2.87         -0.375          0.165
#
#    rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct
# 0       -0.005         -0.023810         -0.016865       -0.000975
# 1       -0.505         -0.119048          0.082341       -0.098441
# 2       -0.255         -0.071429          0.032738       -0.049708
# 3        0.245          0.023810         -0.066468        0.047758
# 4       -0.255         -0.071429          0.032738       -0.049708
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119696 entries, 0 to 119695
# Data columns (total 60 columns):
# Unnamed: 0                    119696 non-null int64
# Unnamed: 0.1                  119696 non-null int64
# id                            119696 non-null int64
# origChannel                   119696 non-null int64
# origIntRate                   119696 non-null float64
# origUPB                       119696 non-null int64
# origDate                      119696 non-null object
# firstPmtDate                  119696 non-null object
# origLTV                       119696 non-null float64
# numBorrowers                  119696 non-null float64
# origDebtIncRatio              119696 non-null float64
# borrCreditScore               119696 non-null float64
# loanPurp                      119696 non-null int64
# zipCode                       119696 non-null int64
# pMIperct                      119696 non-null float64
# mortInsType                   119696 non-null float64
# bestCreditScore               119696 non-null float64
# worstCreditScore              119696 non-null float64
# avgCreditScore                119696 non-null float64
# bankNumber                    119696 non-null int64
# stateNumber                   119696 non-null int64
# rptPeriod                     119696 non-null object
# currIntRate                   119696 non-null float64
# currUPB                       119688 non-null float64
# loanAge                       119696 non-null int64
# monMatur                      119696 non-null float64
# mSA                           119696 non-null int64
# zeroBalCode                   119696 non-null float64
# zeroBalDate                   119696 non-null object
# lastPdInstDate                14004 non-null object
# forecloDate                   12695 non-null object
# dispDate                      13162 non-null object
# forecloCost                   13063 non-null float64
# propRepCost                   9985 non-null float64
# recovCosts                    6571 non-null float64
# miscCost                      11487 non-null float64
# holdTaxCost                   11086 non-null float64
# saleProceed                   12944 non-null float64
# credEnhProceed                1990 non-null float64
# repurchProceed                707 non-null float64
# otherForecloProceed           6709 non-null float64
# nonIntUPB                     1292 non-null float64
# prinForgivBal                 2 non-null float64
# repurchMakeWholeProceedFlg    119696 non-null int64
# forecloPrinWriteOffAmnt       1 non-null float64
# servActivIndicator            0 non-null float64
# deliqGood                     119696 non-null int64
# deliqBad                      119696 non-null int64
# deliqMax                      119696 non-null float64
# fmacRateMax                   119696 non-null float64
# fmacRateMin                   119696 non-null float64
# fmacRateAvg                   119696 non-null float64
# fmacRateVolatility            119696 non-null float64
# fredRate                      119696 non-null float64
# rateDiffAbove                 119696 non-null float64
# rateDiffBelow                 119696 non-null float64
# rateDiffAvg                   119696 non-null float64
# rateDiffAbovePct              119696 non-null float64
# rateDiffBelowPct              119696 non-null float64
# rateDiffAvgPct                119696 non-null float64
# dtypes: float64(39), int64(14), object(7)
# memory usage: 54.8+ MB

# %% [markdown]
# ## Remove columns not involved in 'Foreclosure or Not' query

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1','id','firstPmtDate','rptPeriod','currIntRate','currUPB','loanAge','monMatur',\
         'zeroBalDate','lastPdInstDate','forecloDate','dispDate','forecloCost','propRepCost','recovCosts',\
         'miscCost','holdTaxCost','saleProceed','credEnhProceed','repurchProceed','otherForecloProceed',\
         'nonIntUPB','prinForgivBal','repurchMakeWholeProceedFlg','forecloPrinWriteOffAmnt','servActivIndicator',\
         'deliqGood','deliqBad','deliqMax'],1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119696 entries, 0 to 119695
# Data columns (total 30 columns):
# origChannel           119696 non-null int64
# origIntRate           119696 non-null float64
# origUPB               119696 non-null int64
# origDate              119696 non-null object
# origLTV               119696 non-null float64
# numBorrowers          119696 non-null float64
# origDebtIncRatio      119696 non-null float64
# borrCreditScore       119696 non-null float64
# loanPurp              119696 non-null int64
# zipCode               119696 non-null int64
# pMIperct              119696 non-null float64
# mortInsType           119696 non-null float64
# bestCreditScore       119696 non-null float64
# worstCreditScore      119696 non-null float64
# avgCreditScore        119696 non-null float64
# bankNumber            119696 non-null int64
# stateNumber           119696 non-null int64
# mSA                   119696 non-null int64
# zeroBalCode           119696 non-null float64
# fmacRateMax           119696 non-null float64
# fmacRateMin           119696 non-null float64
# fmacRateAvg           119696 non-null float64
# fmacRateVolatility    119696 non-null float64
# fredRate              119696 non-null float64
# rateDiffAbove         119696 non-null float64
# rateDiffBelow         119696 non-null float64
# rateDiffAvg           119696 non-null float64
# rateDiffAbovePct      119696 non-null float64
# rateDiffBelowPct      119696 non-null float64
# rateDiffAvgPct        119696 non-null float64
# dtypes: float64(22), int64(7), object(1)
# memory usage: 27.4+ MB

# %% [markdown]
# ## Engineer originDate into Date features

# %%
df['origDate'] = pd.to_datetime(df['origDate'])

# %%
df['origYear'] = df['origDate'].dt.year
df['origMonth'] = df['origDate'].dt.month

# %%
df.drop(['origDate'],1,inplace=True)

# %%
df[['origYear','origMonth']].head()
# Out:
#    origYear  origMonth
# 0      2009          2
# 1      2009          2
# 2      2009          2
# 3      2009          2
# 4      2009          2

# %% [markdown]
# # Turn zero Balance Code Into binary "0" GOOD and "1" BAD

# %%
df.zeroBalCode.unique()
# Out:
# array([ 9.,  1.,  3., 16.,  6.,  2., 15.])

# %%
df['zeroBalCode'] = df.zeroBalCode.replace(1,0)
df['zeroBalCode'] = df.zeroBalCode.replace([9,3,16,6,2,15],1)

# %%
df.zeroBalCode.unique()
# Out:
# array([1., 0.])

# %%
#Checking datatypes of individual feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119696 entries, 0 to 119695
# Data columns (total 31 columns):
# origChannel           119696 non-null int64
# origIntRate           119696 non-null float64
# origUPB               119696 non-null int64
# origLTV               119696 non-null float64
# numBorrowers          119696 non-null float64
# origDebtIncRatio      119696 non-null float64
# borrCreditScore       119696 non-null float64
# loanPurp              119696 non-null int64
# zipCode               119696 non-null int64
# pMIperct              119696 non-null float64
# mortInsType           119696 non-null float64
# bestCreditScore       119696 non-null float64
# worstCreditScore      119696 non-null float64
# avgCreditScore        119696 non-null float64
# bankNumber            119696 non-null int64
# stateNumber           119696 non-null int64
# mSA                   119696 non-null int64
# zeroBalCode           119696 non-null float64
# fmacRateMax           119696 non-null float64
# fmacRateMin           119696 non-null float64
# fmacRateAvg           119696 non-null float64
# fmacRateVolatility    119696 non-null float64
# fredRate              119696 non-null float64
# rateDiffAbove         119696 non-null float64
# rateDiffBelow         119696 non-null float64
# rateDiffAvg           119696 non-null float64
# rateDiffAbovePct      119696 non-null float64
# rateDiffBelowPct      119696 non-null float64
# rateDiffAvgPct        119696 non-null float64
# origYear              119696 non-null int64
# origMonth             119696 non-null int64
# dtypes: float64(22), int64(9)
# memory usage: 28.3 MB

# %% [markdown]
# # Review values for dates and slice (if needed) the timeframe you want

# %%
df.origYear.unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013], dtype=int64)

# %%
df['origMonth'].unique()
# Out:
# array([ 2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12,  1], dtype=int64)

# %% [markdown]
# # Coerce the column dtype (int in this case)

# %%
df = df.astype({'origLTV':'int','numBorrowers':'int','origDebtIncRatio':'int',\
               'borrCreditScore':'int','mortInsType':'int','bestCreditScore':'int',\
               'worstCreditScore':'int','avgCreditScore':'int','zeroBalCode':'int'})
#,'zeroBalCode':'int'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119696 entries, 0 to 119695
# Data columns (total 31 columns):
# origChannel           119696 non-null int64
# origIntRate           119696 non-null float64
# origUPB               119696 non-null int64
# origLTV               119696 non-null int32
# numBorrowers          119696 non-null int32
# origDebtIncRatio      119696 non-null int32
# borrCreditScore       119696 non-null int32
# loanPurp              119696 non-null int64
# zipCode               119696 non-null int64
# pMIperct              119696 non-null float64
# mortInsType           119696 non-null int32
# bestCreditScore       119696 non-null int32
# worstCreditScore      119696 non-null int32
# avgCreditScore        119696 non-null int32
# bankNumber            119696 non-null int64
# stateNumber           119696 non-null int64
# mSA                   119696 non-null int64
# zeroBalCode           119696 non-null int32
# fmacRateMax           119696 non-null float64
# fmacRateMin           119696 non-null float64
# fmacRateAvg           119696 non-null float64
# fmacRateVolatility    119696 non-null float64
# fredRate              119696 non-null float64
# rateDiffAbove         119696 non-null float64
# rateDiffBelow         119696 non-null float64
# rateDiffAvg           119696 non-null float64
# rateDiffAbovePct      119696 non-null float64
# rateDiffBelowPct      119696 non-null float64
# rateDiffAvgPct        119696 non-null float64
# origYear              119696 non-null int64
# origMonth             119696 non-null int64
# dtypes: float64(13), int32(9), int64(9)
# memory usage: 24.2 MB

# %% [markdown]
# <a id='MLReady'></a>

# %% [markdown]
# <a id='MLReady'></a>
# ## *MLReady.csv file loading point
# uncomment one of the boxes below

# %%
#df.to_csv('D:\FM_FULL_EPOCH2_MLReady.csv')

# %%
#df = pd.read_csv('D:\FM_FULL_EPOCH2_MLReady.csv')

# %% [markdown]
# # Oversampling (Since we are starting with only 6.3% of our predicted class)

# %%
good = df.zeroBalCode.value_counts()[0]
bad = df.zeroBalCode.value_counts()[1]
perct_bad = round(good/bad,2)
print(f'We have {perct_bad}% Foreclosures in our dataset')
# Out:
# We have 6.34% Foreclosures in our dataset

# %%
from sklearn.model_selection import train_test_split

training_features, test_features, \
training_target, test_target, = train_test_split(
    df.drop(['zeroBalCode'], axis=1)
    , df['zeroBalCode']
    , test_size = .1
    , random_state=12
)

# %%
# Further split the training data into training/test
x_train, x_val, y_train, y_val = train_test_split(
    training_features
    , training_target
    , test_size = .1
    ,random_state=12
)

# %%
# For the training data, randomly sample 
ros = RandomOverSampler(sampling_strategy='minority')
x_train_res, y_train_res = ros.fit_sample(x_train, y_train)

# %%
print('#############################################')
print('Before oversampling: "Closed" crushes "Default" and causes issues:')
print(training_target.value_counts())
print('')
print('Before oversampling: "Closed" and "Default" are equal')
print(y_train_res.value_counts())
# Out:
# #############################################
# Before oversampling: "Closed" crushes "Default" and causes issues:
# 0    93081
# 1    14645
# Name: zeroBalCode, dtype: int64
#
# Before oversampling: "Closed" and "Default" are equal
# 1    83757
# 0    83757
# Name: zeroBalCode, dtype: int64

# %% [markdown]
# # Recombine X_train_res, y_train_res so PyCaret can deal with one df

# %%
y_train_res.shape
# Out:
# (167514,)

# %%
df = x_train_res.copy()

# %%
df['zeroBalCode'] = y_train_res

# %%
df.shape
# Out:
# (167514, 31)

# %% [markdown]
# # Review metrics last time before run (to have record of starting values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167514 entries, 0 to 167513
# Data columns (total 31 columns):
# origChannel           167514 non-null int64
# origIntRate           167514 non-null float64
# origUPB               167514 non-null int64
# origLTV               167514 non-null int32
# numBorrowers          167514 non-null int32
# origDebtIncRatio      167514 non-null int32
# borrCreditScore       167514 non-null int32
# loanPurp              167514 non-null int64
# zipCode               167514 non-null int64
# pMIperct              167514 non-null float64
# mortInsType           167514 non-null int32
# bestCreditScore       167514 non-null int32
# worstCreditScore      167514 non-null int32
# avgCreditScore        167514 non-null int32
# bankNumber            167514 non-null int64
# stateNumber           167514 non-null int64
# mSA                   167514 non-null int64
# fmacRateMax           167514 non-null float64
# fmacRateMin           167514 non-null float64
# fmacRateAvg           167514 non-null float64
# fmacRateVolatility    167514 non-null float64
# fredRate              167514 non-null float64
# rateDiffAbove         167514 non-null float64
# rateDiffBelow         167514 non-null float64
# rateDiffAvg           167514 non-null float64
# rateDiffAbovePct      167514 non-null float64
# rateDiffBelowPct      167514 non-null float64
# rateDiffAvgPct        167514 non-null float64
# origYear              167514 non-null int64
# origMonth             167514 non-null int64
# zeroBalCode           167514 non-null int32
# dtypes: float64(13), int32(9), int64(9)
# memory usage: 33.9 MB

# %%
df.head()
# Out:
#    origChannel  origIntRate  origUPB  origLTV  numBorrowers  origDebtIncRatio  \
# 0            3        4.625   139000       77             2                36
# 1            2        4.375   398000       70             2                42
# 2            1        4.500   730000       59             2                43
# 3            1        4.500    96000       60             1                42
# 4            1        3.875   111000       85             1                40
#
#    borrCreditScore  loanPurp  zipCode  pMIperct  ...  fredRate  rateDiffAbove  \
# 0              786         2      972       0.0  ...      2.68         -0.245
# 1              712         2      917       0.0  ...      2.58          0.005
# 2              672         2      928       0.0  ...      3.30         -0.300
# 3              632         1      973       0.0  ...      3.30         -0.300
# 4              669         2      843      12.0  ...      2.01         -0.125
#
#    rateDiffBelow  rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  \
# 0          0.155      -0.1850         -0.050308          0.032427
# 1         -0.055       0.0290          0.001144         -0.012731
# 2          0.210      -0.2550         -0.062500          0.044586
# 3          0.210      -0.2550         -0.062500          0.044586
# 4          0.105      -0.1175         -0.031250          0.026382
#
#    rateDiffAvgPct  origYear  origMonth  zeroBalCode
# 0       -0.038462      2009          4            0
# 1        0.006673      2010          9            0
# 2       -0.053628      2011          1            0
# 3       -0.053628      2011          1            0
# 4       -0.029430      2011         11            1
#
# [5 rows x 31 columns]

# %% [markdown]
# # Pycaret - Setup with categorical definition

# %% [markdown]
# ### Use complex setup

# %%
model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , pca = False 
    , ignore_low_variance = True # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value.
    , normalize = True
    , ignore_features = None
    , handle_unknown_categorical = True
    , remove_outliers = True # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
    , bin_numeric_features = [
            'origIntRate'
            , 'origUPB'
            , 'origLTV'
            , 'origDebtIncRatio'
            , 'bestCreditScore'
            , 'avgCreditScore'
            , 'worstCreditScore'
        ] # Set to True to bin numerics using K Means
    , feature_selection = True
    , silent = True
    , profile = False
    , categorical_features = [
            'origChannel'
            , 'numBorrowers'
            , 'loanPurp'
            , 'zipCode'
            , 'bankNumber'
            , 'stateNumber'
            , 'origYear'
            , 'origMonth'
            , 'mSA'
        ]
        , numeric_features = [
            'origIntRate'
            , 'origUPB'
            , 'origLTV'
            , 'pMIperct'
            , 'origDebtIncRatio'
            , 'worstCreditScore'
            , 'bestCreditScore'
            , 'avgCreditScore'
            , 'rateDiffAbove'
            , 'rateDiffBelow'
            , 'rateDiffAvg'
            , 'rateDiffAbovePct'
            , 'rateDiffBelowPct'
            , 'rateDiffAvgPct'
        ]
)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_7ffd017a_9e43_11ea_96f0_309c234564f5row15_col1 {
#             background-color:  lightgreen;
#         }    #T_7ffd017a_9e43_11ea_96f0_309c234564f5row22_col1 {
#             background-color:  lightgreen;
#         }    #T_7ffd017a_9e43_11ea_96f0_309c234564f5row25_col1 {
#             background-color:  lightgreen;
#         }    #T_7ffd017a_9e43_11ea_96f0_309c234564f5row26_col1 {
#             background-color:  lightgreen;
#         }    #T_7ffd017a_9e43_11ea_96f0_309c234564f5row37_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_7ffd017a_9e43_11ea_96f0_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row0_col1" class="data row0 col1" >3214</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row3_col1" class="data row3 col1" >(167514, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row5_col1" class="data row5 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row10_col1" class="data row10 col1" >(111396, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row11_col1" class="data row11 col1" >(77977, 1238)</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row12_col1" class="data row12 col1" >(33419, 1238)</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_7ffd017a_9e43_11ea_96f0_309c234564f5level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_7ffd017a_9e43_11ea_96f0_309c234564f5row17_col0" class="data row17 col0" >Transformation </td>

# %% [markdown]
# ## Compare Models with no blacklist exclusions

# %%
model_results=compare_models() #blacklist = ['tr','ransac'],'lar','par','huber','llar','lasso','en','ridge','omp','br','svm'])
model_results
# Out:
# <style  type="text/css" >
#     #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6e th {
#           text-align: left;
#     }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow10_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow10

# %% [markdown]
# ## Create models

# %% [markdown]
# ### Extra Trees Classifier

# %%
et = create_model('et', fold=10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9663  0.9913  0.9679  0.9649  0.9664  0.9327
# 1       0.9649  0.9927  0.9731  0.9574  0.9651  0.9298
# 2       0.9677  0.9922  0.9715  0.9641  0.9678  0.9354
# 3       0.9647  0.9919  0.9695  0.9602  0.9648  0.9293
# 4       0.9642  0.9923  0.9706  0.9583  0.9644  0.9284
# 5       0.9614  0.9911  0.9670  0.9563  0.9616  0.9228
# 6       0.9679  0.9930  0.9735  0.9627  0.9681  0.9358
# 7       0.9652  0.9911  0.9683  0.9623  0.9653  0.9304
# 8       0.9630  0.9907  0.9688  0.9576  0.9632  0.9259
# 9       0.9617  0.9906  0.9663  0.9575  0.9619  0.9235
# Mean    0.9647  0.9917  0.9696  0.9601  0.9649  0.9294
# SD      0.0021  0.0008  0.0023  0.0030  0.0021  0.0042

# %% [markdown]
# #### CatBoost

# %%
catboost =create_model('catboost', fold = 10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7712  0.8511  0.8309  0.7421  0.7840  0.5425
# 1       0.7651  0.8408  0.8219  0.7378  0.7776  0.5302
# 2       0.7708  0.8491  0.8278  0.7429  0.7831  0.5417
# 3       0.7646  0.8436  0.8350  0.7317  0.7799  0.5292
# 4       0.7699  0.8449  0.8208  0.7448  0.7810  0.5399
# 5       0.7689  0.8497  0.8273  0.7406  0.7815  0.5379
# 6       0.7819  0.8565  0.8344  0.7548  0.7926  0.5638
# 7       0.7662  0.8440  0.8177  0.7410  0.7775  0.5324
# 8       0.7648  0.8422  0.8136  0.7409  0.7756  0.5296
# 9       0.7694  0.8502  0.8293  0.7403  0.7823  0.5388
# Mean    0.7693  0.8472  0.8259  0.7417  0.7815  0.5386
# SD      0.0048  0.0046  0.0068  0.0055  0.0045  0.0097

# %% [markdown]
# #### XGBoost

# %%
#xgboost = create_model('xgboost', fold = 10)

# %% [markdown]
# ## Tune Models

# %% [markdown]
# #### CatBoost

# %%
tuned_catboost = tune_model('catboost') # from fold=50
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8615  0.9303  0.9289  0.8184  0.8702  0.7230
# 1       0.8542  0.9232  0.9163  0.8149  0.8626  0.7084
# 2       0.8570  0.9312  0.9253  0.8140  0.8661  0.7141
# 3       0.8556  0.9290  0.9340  0.8072  0.8660  0.7112
# 4       0.8521  0.9229  0.9163  0.8119  0.8610  0.7043
# 5       0.8548  0.9274  0.9238  0.8117  0.8641  0.7097
# 6       0.8579  0.9301  0.9222  0.8170  0.8664  0.7159
# 7       0.8521  0.9224  0.9230  0.8082  0.8618  0.7043
# 8       0.8590  0.9280  0.9214  0.8190  0.8672  0.7181
# 9       0.8623  0.9355  0.9286  0.8196  0.8707  0.7245
# Mean    0.8567  0.9280  0.9240  0.8142  0.8656  0.7134
# SD      0.0034  0.0040  0.0053  0.0042  0.0031  0.0067

# %% [markdown]
# ### CatBoost had marked improvements on all metrics!!
# #### Improved:  Accuracy AUC   Recall    Precision F1   Kappa
# #### Declined:
#                     Accuracy	 AUC	 Recall	 Prec.	  F1	    Kappa
#     Untuned:  Mean	0.8661	0.7938	0.0730	0.5686	0.1293	0.1014
#     Tuned:    Mean	0.8653	0.7916	0.0385	0.5872	0.0723	0.0564

# %% [markdown]
# # Interpret Models

# %% [markdown]
# ## Extra Tree Classifier (et)

# %%
#interpret_model(et plot = 'summary')

# %%
#interpret_model(et, plot='correlation', feature='avgCreditScore')

# %% [markdown]
# # Predict models

# %%
pred_holdout = predict_model(catboost)
# Out:
#                  Model  Accuracy     AUC  Recall  Prec.      F1  Kappa
# 0  CatBoost Classifier     0.777  0.8541  0.8304   0.75  0.7882  0.554

# %%
pred_holdout_tuned = predict_model(tuned_catboost)
# Out:
#                  Model  Accuracy     AUC  Recall   Prec.      F1  Kappa
# 0  CatBoost Classifier    0.8645  0.9336  0.9286  0.8229  0.8726  0.729

# %% [markdown]
# # The golden moment... put 10% sample test data through the model...

# %%
predictions = predict_model(tuned_catboost, data=df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#    origChannel  origIntRate  origUPB  origLTV  numBorrowers  origDebtIncRatio  \
# 0            3        4.625   139000       77             2                36
# 1            2        4.375   398000       70             2                42
# 2            1        4.500   730000       59             2                43
# 3            1        4.500    96000       60             1                42
# 4            1        3.875   111000       85             1                40
#
#    borrCreditScore  loanPurp  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0              786         2      972       0.0            0              795
# 1              712         2      917       0.0            0              755
# 2              672         2      928       0.0            0              748
# 3              632         1      973       0.0            0              632
# 4              669         2      843      12.0            1              669
#
#    worstCreditScore  avgCreditScore  bankNumber  stateNumber    mSA  \
# 0               786             790           4           38  38900
# 1               712             733          52            4  40140
# 2               672             710           4            4  31080
# 3               632             632          54           38  41420
# 4               669             669          54           46  36260
#
#    fmacRateMax  fmacRateMin  fmacRateAvg  fmacRateVolatility  fredRate  \
# 0         4.87         4.78       4.8100            0.018828      2.68
# 1         4.37         4.32       4.3460            0.011574      2.58
# 2         4.80         4.71       4.7550            0.019108      3.30
# 3         4.80         4.71       4.7550            0.019108      3.30
# 4         4.00         3.98       3.9925            0.005025      2.01
#
#    rateDiffAbove  rateDiffBelow  rateDiffAvg  rateDiffAbovePct  \
# 0         -0.245          0.155      -0.1850         -0.050308
# 1          0.005         -0.055       0.0290          0.001144
# 2         -0.300          0.210      -0.2550         -0.062500
# 3         -0.300          0.210      -0.2550         -0.062500
# 4         -0.125          0.105      -0.1175         -0.031250
#
#    rateDiffBelowPct  rateDiffAvgPct  origYear  origMonth  zeroBalCode  Label  \
# 0          0.032427       -0.038462      2009          4            0      0
# 1         -0.012731        0.006673      2010          9            0      0
# 2          0.044586       -0.053628      2011          1            0      0
# 3          0.044586       -0.053628      2011          1            0      1
# 4          0.026382       -0.029430      2011         11            1      1
#
#     Score
# 0  0.3259
# 1  0.1467
# 2  0.3069
# 3  0.5469
# 4  0.8683

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    94550
# 1    72964
# Name: Label, dtype: int64

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalseNegative'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalsePositive'
    else:
        value = 'Undefined'
    return value

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
print(f'           ##############################')
print(f'           #             #              #')
print(f'         0 #    {confusionMatrix["TrueNegative"]}    #     {confusionMatrix["FalsePositive"]}    #')
print(f'  True     #             #              #')
print(f'  Class    ##############################')
print(f'           #             #              #')
print(f'         1 #    {confusionMatrix["FalseNegative"]}    #     {confusionMatrix["TruePositive"]}    #')
print(f'           #             #              #')
print(f'           ##############################')
print(f'                  0              1        ')
print(f'                  Predicted Class           ')
# Out:
#            ##############################
#            #             #              #
#          0 #    66986    #     27564    #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    16771    #     56193    #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
# 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
trueNegativePct = confusionMatrix['TrueNegative'] / totalNegative * 100
falseNegativePct = confusionMatrix['FalseNegative'] / totalNegative * 100
truePositivePct = confusionMatrix['TruePositive'] / totalPositive * 100
falsePositivePct = confusionMatrix['FalsePositive'] / totalPositive * 100

print(f'TrueNegative:  {round(trueNegativePct,2)}%')
print(f'FalseNegative:  {round(falseNegativePct,2)}%')
print(f'TruePosiive:   {round(truePositivePct,2)}%')
print(f'FalsePositive: {round(falsePositivePct,2)}%')
# Out:
# TrueNegative:  79.98%
# FalseNegative:  20.02%
# TruePosiive:   67.09%
# FalsePositive: 32.91%

# %%
save_model(tuned_catboost, 'tunedCatboost_EPOCH2_Over50_50_052520')
# Out:
# Transformation Pipeline and Model Succesfully Saved
