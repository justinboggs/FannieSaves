# %% [markdown]
# # ML Foreclosure Binary Classification - EPOCH 3 data
#
#     target = zeroBalCode (set to object dtype)
#     Binary classification sets zeroBalCode to either "0" or "1" for the 7 possible outcomes
#
#     "0" = "Loan Success"
#         * 01 = Prepaid or Matured
#
#     "1" =  "Loan Failure" - Most likely loss of money (but not necessarily) one of below conditions:
#         * 02 = Third Party Sale
#         * 03 = Short Sale
#         * 06 = Repurchased
#         * 09 = Deed-in-Lieu,REO
#         * 15 = Note Sale
#         * 16 = Reperforming Loan Sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#!pip install pycaret
from imblearn.over_sampling import RandomOverSampler
from pycaret.classification import *
#from pycaret.regression import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Importing the data - only use *.ML.csv files!!!
# If you have *.MLReady.csv then [click here](#MLReady)

# %%
df=pd.read_csv("data/FM_Acq_Perf_FMAC_EPOCH3_ML.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            id  origChannel  origIntRate  origUPB  \
# 0     1265166       1265166  100495721320            1        4.375   310000
# 1     1265167       1265167  102361386857            1        4.625   142000
# 2     1265168       1265168  102516953457            1        5.000   124000
# 3     1265169       1265169  103711862089            3        4.490   170000
# 4     1265170       1265170  104417831957            3        4.750   100000
#
#      origDate firstPmtDate  origLTV  numBorrowers  ...  fmacRateMin  \
# 0  2013-11-01   2014-01-01     64.0           1.0  ...         4.16
# 1  2013-11-01   2014-01-01     69.0           1.0  ...         4.16
# 2  2013-11-01   2014-01-01     80.0           1.0  ...         4.16
# 3  2013-11-01   2014-01-01     54.0           2.0  ...         4.16
# 4  2013-11-01   2014-01-01     32.0           1.0  ...         4.16
#
#    fmacRateAvg  fmacRateVolatility  fredRate  rateDiffAbove  rateDiffBelow  \
# 0        4.255            0.045673      2.65          0.025         -0.215
# 1        4.255            0.045673      2.65          0.275         -0.465
# 2        4.255            0.045673      2.65          0.650         -0.840
# 3        4.255            0.045673      2.65          0.140         -0.330
# 4        4.255            0.045673      2.65          0.400         -0.590
#
#    rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct
# 0        0.120          0.005747         -0.051683        0.028202
# 1        0.370          0.063218         -0.111779        0.086957
# 2        0.745          0.149425         -0.201923        0.175088
# 3        0.235          0.032184         -0.079327        0.055229
# 4        0.495          0.091954         -0.141827        0.116334
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35388 entries, 0 to 35387
# Data columns (total 60 columns):
# Unnamed: 0                    35388 non-null int64
# Unnamed: 0.1                  35388 non-null int64
# id                            35388 non-null int64
# origChannel                   35388 non-null int64
# origIntRate                   35388 non-null float64
# origUPB                       35388 non-null int64
# origDate                      35388 non-null object
# firstPmtDate                  35388 non-null object
# origLTV                       35388 non-null float64
# numBorrowers                  35388 non-null float64
# origDebtIncRatio              35388 non-null float64
# borrCreditScore               35388 non-null float64
# loanPurp                      35388 non-null int64
# zipCode                       35388 non-null int64
# pMIperct                      35388 non-null float64
# mortInsType                   35388 non-null float64
# bestCreditScore               35388 non-null float64
# worstCreditScore              35388 non-null float64
# avgCreditScore                35388 non-null float64
# bankNumber                    35388 non-null int64
# stateNumber                   35388 non-null int64
# rptPeriod                     35388 non-null object
# currIntRate                   35388 non-null float64
# currUPB                       35387 non-null float64
# loanAge                       35388 non-null int64
# monMatur                      35388 non-null float64
# mSA                           35388 non-null int64
# zeroBalCode                   35388 non-null float64
# zeroBalDate                   35388 non-null object
# lastPdInstDate                1595 non-null object
# forecloDate                   1510 non-null object
# dispDate                      1125 non-null object
# forecloCost                   1124 non-null float64
# propRepCost                   767 non-null float64
# recovCosts                    380 non-null float64
# miscCost                      940 non-null float64
# holdTaxCost                   886 non-null float64
# saleProceed                   1085 non-null float64
# credEnhProceed                297 non-null float64
# repurchProceed                11 non-null float64
# otherForecloProceed           535 non-null float64
# nonIntUPB                     302 non-null float64
# prinForgivBal                 0 non-null float64
# repurchMakeWholeProceedFlg    35388 non-null int64
# forecloPrinWriteOffAmnt       0 non-null float64
# servActivIndicator            0 non-null float64
# deliqGood                     35388 non-null int64
# deliqBad                      35388 non-null int64
# deliqMax                      35388 non-null float64
# fmacRateMax                   35388 non-null float64
# fmacRateMin                   35388 non-null float64
# fmacRateAvg                   35388 non-null float64
# fmacRateVolatility            35388 non-null float64
# fredRate                      35388 non-null float64
# rateDiffAbove                 35388 non-null float64
# rateDiffBelow                 35388 non-null float64
# rateDiffAvg                   35388 non-null float64
# rateDiffAbovePct              35388 non-null float64
# rateDiffBelowPct              35388 non-null float64
# rateDiffAvgPct                35388 non-null float64
# dtypes: float64(39), int64(14), object(7)
# memory usage: 16.2+ MB

# %% [markdown]
# ## Remove columns not involved in 'Foreclosure or Not' query

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1','id','firstPmtDate','rptPeriod','currIntRate','currUPB','loanAge','monMatur',\
         'zeroBalDate','lastPdInstDate','forecloDate','dispDate','forecloCost','propRepCost','recovCosts',\
         'miscCost','holdTaxCost','saleProceed','credEnhProceed','repurchProceed','otherForecloProceed',\
         'nonIntUPB','prinForgivBal','repurchMakeWholeProceedFlg','forecloPrinWriteOffAmnt','servActivIndicator',\
         'deliqGood','deliqBad','deliqMax'],1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35388 entries, 0 to 35387
# Data columns (total 30 columns):
# origChannel           35388 non-null int64
# origIntRate           35388 non-null float64
# origUPB               35388 non-null int64
# origDate              35388 non-null object
# origLTV               35388 non-null float64
# numBorrowers          35388 non-null float64
# origDebtIncRatio      35388 non-null float64
# borrCreditScore       35388 non-null float64
# loanPurp              35388 non-null int64
# zipCode               35388 non-null int64
# pMIperct              35388 non-null float64
# mortInsType           35388 non-null float64
# bestCreditScore       35388 non-null float64
# worstCreditScore      35388 non-null float64
# avgCreditScore        35388 non-null float64
# bankNumber            35388 non-null int64
# stateNumber           35388 non-null int64
# mSA                   35388 non-null int64
# zeroBalCode           35388 non-null float64
# fmacRateMax           35388 non-null float64
# fmacRateMin           35388 non-null float64
# fmacRateAvg           35388 non-null float64
# fmacRateVolatility    35388 non-null float64
# fredRate              35388 non-null float64
# rateDiffAbove         35388 non-null float64
# rateDiffBelow         35388 non-null float64
# rateDiffAvg           35388 non-null float64
# rateDiffAbovePct      35388 non-null float64
# rateDiffBelowPct      35388 non-null float64
# rateDiffAvgPct        35388 non-null float64
# dtypes: float64(22), int64(7), object(1)
# memory usage: 8.1+ MB

# %% [markdown]
# ## Engineer originDate into Date features

# %%
df['origDate'] = pd.to_datetime(df['origDate'])

# %%
df['origYear'] = df['origDate'].dt.year
df['origMonth'] = df['origDate'].dt.month

# %%
df.drop(['origDate'],1,inplace=True)

# %%
df[['origYear','origMonth']].tail()
# Out:
#        origYear  origMonth
# 35383      2019          3
# 35384      2019          3
# 35385      2019          3
# 35386      2019          3
# 35387      2019          3

# %% [markdown]
# # Turn zero Balance Code Into binary "0" GOOD and "1" BAD

# %%
df.zeroBalCode.unique()
# Out:
# array([ 1.,  9., 16.,  3.,  2.,  6., 15.])

# %%
df['zeroBalCode'] = df.zeroBalCode.replace(1,0)
df['zeroBalCode'] = df.zeroBalCode.replace([9,3,16,6,2,15],1)

# %%
df.zeroBalCode.unique()
# Out:
# array([0., 1.])

# %%
#Checking datatypes of individual feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35388 entries, 0 to 35387
# Data columns (total 31 columns):
# origChannel           35388 non-null int64
# origIntRate           35388 non-null float64
# origUPB               35388 non-null int64
# origLTV               35388 non-null float64
# numBorrowers          35388 non-null float64
# origDebtIncRatio      35388 non-null float64
# borrCreditScore       35388 non-null float64
# loanPurp              35388 non-null int64
# zipCode               35388 non-null int64
# pMIperct              35388 non-null float64
# mortInsType           35388 non-null float64
# bestCreditScore       35388 non-null float64
# worstCreditScore      35388 non-null float64
# avgCreditScore        35388 non-null float64
# bankNumber            35388 non-null int64
# stateNumber           35388 non-null int64
# mSA                   35388 non-null int64
# zeroBalCode           35388 non-null float64
# fmacRateMax           35388 non-null float64
# fmacRateMin           35388 non-null float64
# fmacRateAvg           35388 non-null float64
# fmacRateVolatility    35388 non-null float64
# fredRate              35388 non-null float64
# rateDiffAbove         35388 non-null float64
# rateDiffBelow         35388 non-null float64
# rateDiffAvg           35388 non-null float64
# rateDiffAbovePct      35388 non-null float64
# rateDiffBelowPct      35388 non-null float64
# rateDiffAvgPct        35388 non-null float64
# origYear              35388 non-null int64
# origMonth             35388 non-null int64
# dtypes: float64(22), int64(9)
# memory usage: 8.4 MB

# %% [markdown]
# # Review values for dates and slice (if needed) the timeframe you want

# %%
df.origYear.unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
df['origMonth'].unique()
# Out:
# array([11, 12,  1,  2,  3,  5,  4,  6,  7,  9,  8, 10], dtype=int64)

# %% [markdown]
# # Coerce the column dtype (int in this case)

# %%
df = df.astype({'origLTV':'int','numBorrowers':'int','origDebtIncRatio':'int',\
               'borrCreditScore':'int','mortInsType':'int','bestCreditScore':'int',\
               'worstCreditScore':'int','avgCreditScore':'int','zeroBalCode':'int'})
#,'zeroBalCode':'int'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35388 entries, 0 to 35387
# Data columns (total 31 columns):
# origChannel           35388 non-null int64
# origIntRate           35388 non-null float64
# origUPB               35388 non-null int64
# origLTV               35388 non-null int32
# numBorrowers          35388 non-null int32
# origDebtIncRatio      35388 non-null int32
# borrCreditScore       35388 non-null int32
# loanPurp              35388 non-null int64
# zipCode               35388 non-null int64
# pMIperct              35388 non-null float64
# mortInsType           35388 non-null int32
# bestCreditScore       35388 non-null int32
# worstCreditScore      35388 non-null int32
# avgCreditScore        35388 non-null int32
# bankNumber            35388 non-null int64
# stateNumber           35388 non-null int64
# mSA                   35388 non-null int64
# zeroBalCode           35388 non-null int32
# fmacRateMax           35388 non-null float64
# fmacRateMin           35388 non-null float64
# fmacRateAvg           35388 non-null float64
# fmacRateVolatility    35388 non-null float64
# fredRate              35388 non-null float64
# rateDiffAbove         35388 non-null float64
# rateDiffBelow         35388 non-null float64
# rateDiffAvg           35388 non-null float64
# rateDiffAbovePct      35388 non-null float64
# rateDiffBelowPct      35388 non-null float64
# rateDiffAvgPct        35388 non-null float64
# origYear              35388 non-null int64
# origMonth             35388 non-null int64
# dtypes: float64(13), int32(9), int64(9)
# memory usage: 7.2 MB

# %% [markdown]
# <a id='MLReady'></a>

# %% [markdown]
# <a id='MLReady'></a>
# ## *MLReady.csv file loading point
# uncomment one of the boxes below

# %%
#df.to_csv('D:\FM_FULL_EPOCH3_MLReady.csv')

# %%
#df = pd.read_csv('D:\FM_FULL_EPOCH2_MLReady.csv')

# %% [markdown]
# # Oversampling (Since we are starting with only 6.3% of our predicted class)

# %%
good = df.zeroBalCode.value_counts()[0]
bad = df.zeroBalCode.value_counts()[1]
perct_bad = round(good/bad,2)
print(f'We have {perct_bad}% Foreclosures in our dataset')
# Out:
# We have 17.17% Foreclosures in our dataset

# %%
from sklearn.model_selection import train_test_split

training_features, test_features, \
training_target, test_target, = train_test_split(
    df.drop(['zeroBalCode'], axis=1)
    , df['zeroBalCode']
    , test_size = .1
    , random_state=12
)

# %%
# Further split the training data into training/test
x_train, x_val, y_train, y_val = train_test_split(
    training_features
    , training_target
    , test_size = .1
    ,random_state=12
)

# %%
# For the training data, randomly sample 
ros = RandomOverSampler(sampling_strategy='minority')
x_train_res, y_train_res = ros.fit_sample(x_train, y_train)

# %%
print('#############################################')
print('Before oversampling: "Closed" crushes "Default" and causes issues:')
print(training_target.value_counts())
print('')
print('Before oversampling: "Closed" and "Default" are equal')
print(y_train_res.value_counts())
# Out:
# #############################################
# Before oversampling: "Closed" crushes "Default" and causes issues:
# 0    30081
# 1     1768
# Name: zeroBalCode, dtype: int64
#
# Before oversampling: "Closed" and "Default" are equal
# 1    27077
# 0    27077
# Name: zeroBalCode, dtype: int64

# %% [markdown]
# # Recombine X_train_res, y_train_res so PyCaret can deal with one df

# %%
y_train_res.shape
# Out:
# (54154,)

# %%
df = x_train_res.copy()

# %%
df['zeroBalCode'] = y_train_res

# %%
df.shape
# Out:
# (54154, 31)

# %% [markdown]
# # Review metrics last time before run (to have record of starting values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54154 entries, 0 to 54153
# Data columns (total 31 columns):
# origChannel           54154 non-null int64
# origIntRate           54154 non-null float64
# origUPB               54154 non-null int64
# origLTV               54154 non-null int32
# numBorrowers          54154 non-null int32
# origDebtIncRatio      54154 non-null int32
# borrCreditScore       54154 non-null int32
# loanPurp              54154 non-null int64
# zipCode               54154 non-null int64
# pMIperct              54154 non-null float64
# mortInsType           54154 non-null int32
# bestCreditScore       54154 non-null int32
# worstCreditScore      54154 non-null int32
# avgCreditScore        54154 non-null int32
# bankNumber            54154 non-null int64
# stateNumber           54154 non-null int64
# mSA                   54154 non-null int64
# fmacRateMax           54154 non-null float64
# fmacRateMin           54154 non-null float64
# fmacRateAvg           54154 non-null float64
# fmacRateVolatility    54154 non-null float64
# fredRate              54154 non-null float64
# rateDiffAbove         54154 non-null float64
# rateDiffBelow         54154 non-null float64
# rateDiffAvg           54154 non-null float64
# rateDiffAbovePct      54154 non-null float64
# rateDiffBelowPct      54154 non-null float64
# rateDiffAvgPct        54154 non-null float64
# origYear              54154 non-null int64
# origMonth             54154 non-null int64
# zeroBalCode           54154 non-null int32
# dtypes: float64(13), int32(9), int64(9)
# memory usage: 10.9 MB

# %%
df.head()
# Out:
#    origChannel  origIntRate  origUPB  origLTV  numBorrowers  origDebtIncRatio  \
# 0            2        4.250   206000       80             2                32
# 1            1        4.250   205000       65             1                25
# 2            3        4.125   295000       69             1                44
# 3            1        4.750   475000       76             2                30
# 4            1        4.500    85000       46             2                35
#
#    borrCreditScore  loanPurp  zipCode  pMIperct  ...  fredRate  rateDiffAbove  \
# 0              751         2      750       0.0  ...      2.17          0.340
# 1              692         1      925       0.0  ...      2.17          0.520
# 2              691         2      946       0.0  ...      1.87          0.425
# 3              638         2      906       0.0  ...      1.46          1.270
# 4              637         1      570       0.0  ...      2.43          0.410
#
#    rateDiffBelow  rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  \
# 0         -0.390        0.360          0.086957         -0.101036
# 1         -0.620        0.580          0.139410         -0.170799
# 2         -0.475        0.453          0.114865         -0.130137
# 3         -1.340        1.310          0.364943         -0.392962
# 4         -0.520        0.454          0.100244         -0.130653
#
#    rateDiffAvgPct  origYear  origMonth  zeroBalCode
# 0        0.092545      2015          9            0
# 1        0.158038      2015          1            0
# 2        0.123366      2015          4            0
# 3        0.380814      2016          7            0
# 4        0.112210      2015          7            0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Pycaret - Setup with categorical definition

# %% [markdown]
# ### Use complex setup

# %%
model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , pca = False 
    , ignore_low_variance = True # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value.
    , normalize = True
    , ignore_features = None
    , handle_unknown_categorical = True
    , remove_outliers = True # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
    , bin_numeric_features = [
            'origIntRate'
            , 'origUPB'
            , 'origLTV'
            , 'origDebtIncRatio'
            , 'bestCreditScore'
            , 'avgCreditScore'
            , 'worstCreditScore'
        ] # Set to True to bin numerics using K Means
    , feature_selection = True
    , silent = True
    , profile = False
    , categorical_features = [
            'origChannel'
            , 'numBorrowers'
            , 'loanPurp'
            , 'zipCode'
            , 'bankNumber'
            , 'stateNumber'
            , 'origYear'
            , 'origMonth'
            , 'mSA'
        ]
        , numeric_features = [
            'origIntRate'
            , 'origUPB'
            , 'origLTV'
            , 'pMIperct'
            , 'origDebtIncRatio'
            , 'worstCreditScore'
            , 'bestCreditScore'
            , 'avgCreditScore'
            , 'rateDiffAbove'
            , 'rateDiffBelow'
            , 'rateDiffAvg'
            , 'rateDiffAbovePct'
            , 'rateDiffBelowPct'
            , 'rateDiffAvgPct'
        ]
)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_db895234_9e59_11ea_85bf_309c234564f5row15_col1 {
#             background-color:  lightgreen;
#         }    #T_db895234_9e59_11ea_85bf_309c234564f5row22_col1 {
#             background-color:  lightgreen;
#         }    #T_db895234_9e59_11ea_85bf_309c234564f5row25_col1 {
#             background-color:  lightgreen;
#         }    #T_db895234_9e59_11ea_85bf_309c234564f5row26_col1 {
#             background-color:  lightgreen;
#         }    #T_db895234_9e59_11ea_85bf_309c234564f5row37_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_db895234_9e59_11ea_85bf_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row0_col1" class="data row0 col1" >291</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row3_col1" class="data row3 col1" >(54154, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row5_col1" class="data row5 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row10_col1" class="data row10 col1" >(51446, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row11_col1" class="data row11 col1" >(36012, 1110)</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row12_col1" class="data row12 col1" >(15434, 1110)</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_db895234_9e59_11ea_85bf_309c234564f5level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_db895234_9e59_11ea_85bf_309c234564f5row17_col0" class="data row17 col0" >Transformation </td>

# %% [markdown]
# ## Compare Models with no blacklist exclusions

# %%
model_results=compare_models() #blacklist = ['tr','ransac'],'lar','par','huber','llar','lasso','en','ridge','omp','br','svm'])
model_results
# Out:
# <style  type="text/css" >
#     #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6e th {
#           text-align: left;
#     }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow10_col0 {
#             text-align:  left;
#         }    #T_6fcb05ee_9db3_11ea_b3c3_24ee9a7c8c6erow10

# %% [markdown]
# ## Create models

# %% [markdown]
# ### Extra Trees Classifier

# %%
et = create_model('et', fold=10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9663  0.9913  0.9679  0.9649  0.9664  0.9327
# 1       0.9649  0.9927  0.9731  0.9574  0.9651  0.9298
# 2       0.9677  0.9922  0.9715  0.9641  0.9678  0.9354
# 3       0.9647  0.9919  0.9695  0.9602  0.9648  0.9293
# 4       0.9642  0.9923  0.9706  0.9583  0.9644  0.9284
# 5       0.9614  0.9911  0.9670  0.9563  0.9616  0.9228
# 6       0.9679  0.9930  0.9735  0.9627  0.9681  0.9358
# 7       0.9652  0.9911  0.9683  0.9623  0.9653  0.9304
# 8       0.9630  0.9907  0.9688  0.9576  0.9632  0.9259
# 9       0.9617  0.9906  0.9663  0.9575  0.9619  0.9235
# Mean    0.9647  0.9917  0.9696  0.9601  0.9649  0.9294
# SD      0.0021  0.0008  0.0023  0.0030  0.0021  0.0042

# %% [markdown]
# #### CatBoost

# %%
catboost =create_model('catboost', fold = 10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7712  0.8511  0.8309  0.7421  0.7840  0.5425
# 1       0.7651  0.8408  0.8219  0.7378  0.7776  0.5302
# 2       0.7708  0.8491  0.8278  0.7429  0.7831  0.5417
# 3       0.7646  0.8436  0.8350  0.7317  0.7799  0.5292
# 4       0.7699  0.8449  0.8208  0.7448  0.7810  0.5399
# 5       0.7689  0.8497  0.8273  0.7406  0.7815  0.5379
# 6       0.7819  0.8565  0.8344  0.7548  0.7926  0.5638
# 7       0.7662  0.8440  0.8177  0.7410  0.7775  0.5324
# 8       0.7648  0.8422  0.8136  0.7409  0.7756  0.5296
# 9       0.7694  0.8502  0.8293  0.7403  0.7823  0.5388
# Mean    0.7693  0.8472  0.8259  0.7417  0.7815  0.5386
# SD      0.0048  0.0046  0.0068  0.0055  0.0045  0.0097

# %% [markdown]
# #### Light Gradient Boosting Machine (lgbm)

# %%
lightgbm = create_model('lightgbm', fold = 10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7417  0.8248  0.7998  0.7163  0.7558  0.4835
# 1       0.7394  0.8146  0.8054  0.7112  0.7554  0.4789
# 2       0.7474  0.8251  0.8085  0.7202  0.7618  0.4948
# 3       0.7384  0.8155  0.8065  0.7096  0.7549  0.4768
# 4       0.7365  0.8148  0.7954  0.7113  0.7510  0.4730
# 5       0.7443  0.8226  0.8060  0.7172  0.7590  0.4886
# 6       0.7569  0.8326  0.8139  0.7303  0.7698  0.5138
# 7       0.7436  0.8178  0.7997  0.7187  0.7571  0.4873
# 8       0.7403  0.8175  0.7918  0.7175  0.7528  0.4806
# 9       0.7471  0.8235  0.8077  0.7201  0.7614  0.4942
# Mean    0.7436  0.8209  0.8035  0.7172  0.7579  0.4872
# SD      0.0056  0.0055  0.0063  0.0057  0.0051  0.0112

# %% [markdown]
# ## Tune Models

# %% [markdown]
# #### Tuned CatBoost

# %%
tuned_catboost = tune_model('catboost') # from fold=50
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8615  0.9303  0.9289  0.8184  0.8702  0.7230
# 1       0.8542  0.9232  0.9163  0.8149  0.8626  0.7084
# 2       0.8570  0.9312  0.9253  0.8140  0.8661  0.7141
# 3       0.8556  0.9290  0.9340  0.8072  0.8660  0.7112
# 4       0.8521  0.9229  0.9163  0.8119  0.8610  0.7043
# 5       0.8548  0.9274  0.9238  0.8117  0.8641  0.7097
# 6       0.8579  0.9301  0.9222  0.8170  0.8664  0.7159
# 7       0.8521  0.9224  0.9230  0.8082  0.8618  0.7043
# 8       0.8590  0.9280  0.9214  0.8190  0.8672  0.7181
# 9       0.8623  0.9355  0.9286  0.8196  0.8707  0.7245
# Mean    0.8567  0.9280  0.9240  0.8142  0.8656  0.7134
# SD      0.0034  0.0040  0.0053  0.0042  0.0031  0.0067

# %% [markdown]
# ### CatBoost had marked improvements on all metrics!!
# #### Improved:  Accuracy AUC   Recall    Precision F1   Kappa
# #### Declined:
#                     Accuracy	 AUC	 Recall	 Prec.	  F1	    Kappa
#     Untuned:  Mean	0.7693	0.8472	0.8259	0.7417	0.7815	0.5386
#     Tuned:    Mean	0.8567	0.9280	0.9240	0.8142	0.8656	0.7134

# %% [markdown]
# #### Light GBM

# %%
tuned_lightgbm = tune_model('lightgbm') # fold=10
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8630  0.9298  0.9312  0.8193  0.8717  0.7261
# 1       0.8568  0.9235  0.9186  0.8173  0.8650  0.7135
# 2       0.8669  0.9332  0.9351  0.8227  0.8753  0.7338
# 3       0.8686  0.9348  0.9438  0.8202  0.8777  0.7371
# 4       0.8570  0.9236  0.9222  0.8157  0.8657  0.7141
# 5       0.8716  0.9317  0.9379  0.8280  0.8795  0.7433
# 6       0.8651  0.9311  0.9276  0.8244  0.8729  0.7302
# 7       0.8630  0.9290  0.9312  0.8193  0.8717  0.7261
# 8       0.8597  0.9228  0.9240  0.8185  0.8681  0.7194
# 9       0.8760  0.9390  0.9425  0.8317  0.8836  0.7520
# Mean    0.8648  0.9298  0.9314  0.8217  0.8731  0.7296
# SD      0.0059  0.0050  0.0081  0.0048  0.0057  0.0118

# %% [markdown]
# ### LigthGBM had marked improvements on all metrics!!
# #### Improved:  Accuracy AUC   Recall    Precision F1   Kappa
# #### Declined:
#                     Accuracy	 AUC	 Recall	 Prec.	  F1	    Kappa
#     Untuned:  Mean	0.7436	0.8209	0.8035	0.7172	0.7579	0.4872
#     Tuned:    Mean	0.8648	0.9298	0.9314	0.8217	0.8731	0.7296

# %%
plot_model(tuned_lightgbm, plot = 'vc')

# %% [markdown]
# ### Let's see if we can improve with more folds set at 50

# %%
tuned_lightgbm50 = tune_model('lightgbm', fold=50) # fold = 50
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8494  0.9314  0.9154  0.8086  0.8587  0.6987
# 1       0.8801  0.9418  0.9410  0.8389  0.8870  0.7603
# 2       0.8750  0.9414  0.9538  0.8239  0.8841  0.7500
# 3       0.8808  0.9346  0.9487  0.8352  0.8884  0.7615
# 4       0.8750  0.9360  0.9321  0.8366  0.8817  0.7500
# 5       0.8603  0.9160  0.9449  0.8081  0.8712  0.7205
# 6       0.8519  0.9335  0.9205  0.8095  0.8614  0.7038
# 7       0.8692  0.9335  0.9243  0.8324  0.8759  0.7385
# 8       0.8468  0.9204  0.9127  0.8061  0.8561  0.6936
# 9       0.8827  0.9466  0.9409  0.8425  0.8890  0.7654
# 10      0.8679  0.9335  0.9332  0.8252  0.8759  0.7359
# 11      0.8692  0.9343  0.9384  0.8241  0.8776  0.7385
# 12      0.8712  0.9343  0.9371  0.8277  0.8790  0.7424
# 13      0.8731  0.9465  0.9397  0.8290  0.8809  0.7462
# 14      0.8840  0.9416  0.9564  0.8352  0.8917  0.7680
# 15      0.8609  0.9352  0.9409  0.8108  0.8711  0.7219
# 16      0.8647  0.9328  0.9397  0.8170  0.8740  0.7295
# 17      0.8686  0.9353  0.9448  0.8196  0.8778  0.7372
# 18      0.8891  0.9447  0.9628  0.8389  0.8966  0.7782
# 19      0.8705  0.9375  0.9320  0.8297  0.8779  0.7411
# 20      0.8782  0.9339  0.9332  0.8405  0.8844  0.7564
# 21      0.8673  0.9330  0.9371  0.8221  0.8758  0.7347
# 22      0.8686  0.9403  0.9320  0.8269  0.8763  0.7372
# 23      0.8660  0.9244  0.9307  0.8239  0.8740  0.7321
# 24      0.8795  0.9417  0.9371  0.8400  0.8859  0.7590
# 25      0.8699  0.9375  0.9409  0.8236  0.8784  0.7398
# 26      0.8737  0.9366  0.9371  0.8314  0.8811  0.7475
# 27      0.8807  0.9438  0.9448  0.8373  0.8878  0.7614
# 28      0.8659  0.9350  0.9576  0.8091  0.8771  0.7319
# 29      0.8871  0.9420  0.9487  0.8446  0.8936  0.7742
# 30      0.8833  0.9488  0.9397  0.8443  0.8894  0.7665
# 31      0.8807  0.9432  0.9371  0.8420  0.8870  0.7614
# 32      0.8756  0.9390  0.9307  0.8382  0.8820  0.7511
# 33      0.8762  0.9415  0.9397  0.8337  0.8835  0.7524
# 34      0.8756  0.9468  0.9358  0.8351  0.8826  0.7511
# 35      0.8691  0.9369  0.9281  0.8301  0.8764  0.7383
# 36      0.8704  0.9357  0.9204  0.8366  0.8765  0.7409
# 37      0.8775  0.9471  0.9525  0.8281  0.8860  0.7550
# 38      0.8820  0.9483  0.9499  0.8362  0.8894  0.7640
# 39      0.8679  0.9271  0.9409  0.8208  0.8768  0.7358
# 40      0.8743  0.9427  0.9435  0.8286  0.8824  0.7486
# 41      0.8768  0.9416  0.9576  0.8243  0.8860  0.7537
# 42      0.8666  0.9301  0.9230  0.8293  0.8736  0.7332
# 43      0.8839  0.9409  0.9474  0.8405  0.8908  0.7678
# 44      0.8627  0.9256  0.9217  0.8243  0.8703  0.7255
# 45      0.8775  0.9418  0.9358  0.8379  0.8842  0.7550
# 46      0.8653  0.9340  0.9487  0.8130  0.8756  0.7306
# 47      0.8762  0.9411  0.9589  0.8227  0.8856  0.7524
# 48      0.8756  0.9317  0.9474  0.8283  0.8838  0.7511
# 49      0.8717  0.9345  0.9461  0.8235  0.8805  0.7434
# Mean    0.8723  0.9372  0.9393  0.8283  0.8803  0.7447
# SD      0.0089  0.0069  0.0112  0.0103  0.0081  0.0177

# %% [markdown]
# ### LigthGBM continued to improve on all metrics!!
# #### Improved:  Accuracy AUC   Recall    Precision F1   Kappa
# #### Declined:
#                     Accuracy	 AUC	 Recall	 Prec.	  F1	    Kappa
#     Untuned:  Mean	0.7436	0.8209	0.8035	0.7172	0.7579	0.4872
#     Tuned10:  Mean	0.8648	0.9298	0.9314	0.8217	0.8731	0.7296
#     Tuned50:  Mean	0.8723	0.9372	0.9393	0.8283	0.8803	0.7447

# %% [markdown]
# ### Let's see if we can improve with more folds set at 100

# %%
tuned_lightgbm100 = tune_model('lightgbm', fold=100) # fold = 50
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8564  0.9319  0.9333  0.8089  0.8667  0.7128
# 1       0.8590  0.9268  0.8974  0.8333  0.8642  0.7179
# 2       0.8833  0.9413  0.9487  0.8390  0.8905  0.7667
# 3       0.8603  0.9394  0.9385  0.8115  0.8704  0.7205
# 4       0.8756  0.9423  0.9538  0.8248  0.8847  0.7513
# 5       0.8923  0.9441  0.9564  0.8477  0.8988  0.7846
# 6       0.8692  0.9280  0.9487  0.8186  0.8789  0.7385
# 7       0.8795  0.9347  0.9385  0.8394  0.8862  0.7590
# 8       0.8744  0.9381  0.9205  0.8427  0.8799  0.7487
# 9       0.8987  0.9535  0.9564  0.8575  0.9042  0.7974
# 10      0.8615  0.9143  0.9359  0.8147  0.8711  0.7231
# 11      0.8897  0.9387  0.9564  0.8439  0.8966  0.7795
# 12      0.8449  0.9312  0.9308  0.7943  0.8571  0.6897
# 13      0.8641  0.9377  0.9179  0.8287  0.8710  0.7282
# 14      0.8782  0.9333  0.9410  0.8360  0.8854  0.7564
# 15      0.8731  0.9309  0.9308  0.8345  0.8800  0.7462
# 16      0.8462  0.9191  0.9128  0.8054  0.8558  0.6923
# 17      0.8692  0.9348  0.9487  0.8186  0.8789  0.7385
# 18      0.8936  0.9443  0.9513  0.8529  0.8994  0.7872
# 19      0.8769  0.9404  0.9436  0.8326  0.8846  0.7538
# 20      0.8782  0.9401  0.9359  0.8391  0.8848  0.7564
# 21      0.8590  0.9229  0.9462  0.8057  0.8703  0.7179
# 22      0.9154  0.9656  0.9564  0.8839  0.9187  0.8308
# 23      0.8564  0.9329  0.9359  0.8075  0.8670  0.7128
# 24      0.8667  0.9309  0.9359  0.8221  0.8753  0.7333
# 25      0.8846  0.9460  0.9462  0.8425  0.8913  0.7692
# 26      0.8769  0.9445  0.9462  0.8311  0.8849  0.7538
# 27      0.8821  0.9518  0.9359  0.8449  0.8881  0.7641
# 28      0.8654  0.9391  0.9487  0.8132  0.8757  0.7308
# 29      0.8808  0.9443  0.9410  0.8398  0.8875  0.7615
# ...        ...     ...     ...     ...     ...     ...
# 72      0.8744  0.9341  0.9357  0.8330  0.8814  0.7488
# 73      0.8756  0.9373  0.9306  0.8380  0.8819  0.7514
# 74      0.8821  0.9392  0.9614  0.8293  0.8905  0.7642
# 75      0.8756  0.9458  0.9512  0.8259  0.8841  0.7514
# 76      0.8667  0.9331  0.9357  0.8217  0.8750  0.7334
# 77      0.8883  0.9597  0.9512  0.8447  0.8948  0.7767
# 78      0.8845  0.9355  0.9512  0.8390  0.8916  0.7690
# 79      0.8537  0.9238  0.9203  0.8118  0.8627  0.7074
# 80      0.8691  0.9394  0.9383  0.8239  0.8774  0.7382
# 81      0.8691  0.9346  0.9203  0.8345  0.8753  0.7382
# 82      0.8832  0.9440  0.9537  0.8356  0.8908  0.7664
# 83      0.8858  0.9481  0.9563  0.8378  0.8932  0.7715
# 84      0.8703  0.9298  0.9512  0.8186  0.8799  0.7407
# 85      0.8806  0.9434  0.9306  0.8458  0.8862  0.7613
# 86      0.8729  0.9372  0.9357  0.8311  0.8803  0.7459
# 87      0.8858  0.9409  0.9357  0.8505  0.8911  0.7715
# 88      0.8614  0.9246  0.9254  0.8200  0.8696  0.7228
# 89      0.8575  0.9323  0.9280  0.8131  0.8667  0.7151
# 90      0.8973  0.9538  0.9486  0.8601  0.9022  0.7946
# 91      0.8845  0.9478  0.9409  0.8453  0.8905  0.7690
# 92      0.8665  0.9343  0.9383  0.8202  0.8753  0.7330
# 93      0.8755  0.9509  0.9537  0.8244  0.8844  0.7510
# 94      0.8935  0.9583  0.9460  0.8558  0.8987  0.7869
# 95      0.8896  0.9461  0.9460  0.8499  0.8954  0.7792
# 96      0.8691  0.9230  0.9460  0.8196  0.8783  0.7382
# 97      0.8742  0.9459  0.9383  0.8314  0.8816  0.7484
# 98      0.8691  0.9364  0.9409  0.8225  0.8777  0.7382
# 99      0.8665  0.9340  0.9434  0.8174  0.8759  0.7330
# Mean    0.8739  0.9383  0.9399  0.8303  0.8816  0.7477
# SD      0.0128  0.0097  0.0129  0.0158  0.0115  0.0257
#
# [102 rows x 6 columns]

# %% [markdown]
# ### LigthGBM continued to improve on all metrics!!
# #### Improved:  Accuracy AUC   Recall    Precision F1   Kappa
# #### Declined:
#                     Accuracy	 AUC	 Recall	 Prec.	  F1	    Kappa
#     Untuned:  Mean	0.7436	0.8209	0.8035	0.7172	0.7579	0.4872
#     Tuned10:  Mean	0.8648	0.9298	0.9314	0.8217	0.8731	0.7296
#     Tuned50:  Mean	0.8723	0.9372	0.9393	0.8283	0.8803	0.7447
#     Tuned100: Mean	0.8739	0.9383	0.9399	0.8303	0.8816	0.7477

# %%
plot_model(tuned_lightgbm100, plot = 'feature')

# %% [markdown]
# #### XGBoost

# %%
#tuned_xgboost = tune_model('xgboost')

# %% [markdown]
# Didn't tune xgboost since it takes about 5 hours and I don't see a big benefit tuning the above models

# %% [markdown]
# ## Ensemble models

# %%
#catboost_bagged = ensemble_model(catboost)

# %% [markdown]
# ### CatBoost had great improvements with Ensemble Bagging
# #### Improved:  Accuracy   AUC   Recall   F1   Kappa
# #### Declined:   Precision
#                     Accuracy	 AUC	 Recall	 Prec.	  F1	    Kappa
#     Untuned:  Mean	0.8661	0.7938	0.0730	0.5686	0.1293	0.1014
#     Bagging:  Mean	0.8664	0.7972	0.0837	0.5637	0.1456	0.1145

# %%
#catboost_boosted = ensemble_model(catboost)

# %% [markdown]
# ## Blend 3 chosen Models

# %% [markdown]
# #### First blend 'non-tuned' models

# %%
#blend3 = blend_models(estimator_list = [catboost, lightgbm, xgboost])

# %% [markdown]
# #### Next blend tuned models

# %% [markdown]
# ## Evaluate Models

# %%
plot_model(tuned_lightgbm)

# %%
plot_model(tuned_lightgbm, plot = 'threshold')

# %%
plot_model(tuned_lightgbm, plot = 'pr')

# %%
plot_model(tuned_lightgbm, plot='confusion_matrix')

# %%
plot_model(tuned_lightgbm, plot = 'error')

# %%
plot_model(tuned_lightgbm, plot = 'class_report')

# %%
plot_model(tuned_lightgbm, plot = 'boundary')

# %%
plot_model(tuned_lightgbm, plot='learning')

# %%
plot_model(tuned_lightgbm, plot = 'calibration')

# %%
plot_model(tuned_lightgbm, plot = 'vc')

# %%
plot_model(tuned_lightgbm, plot='dimension')

# %%
plot_model(tuned_lightgbm, plot = 'feature')

# %%
plot_model(tuned_lightgbm, plot = 'parameter')
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree           1
# importance_type        split
# learning_rate            0.4
# max_depth                 40
# min_child_samples         20
# min_child_weight       0.001
# min_split_gain           0.2
# n_estimators             200
# n_jobs                    -1
# num_leaves               100
# objective               None
# random_state            3214
# reg_alpha                0.3
# reg_lambda               0.1
# silent                  True
# subsample                  1
# subsample_for_bin     200000
# subsample_freq             0

# %%
#blendTuned3 = blend_models(estimator_list = [tuned_catboost, tuned_lightgbm, tuned_xgboost])

# %% [markdown]
# # Interpret Models

# %% [markdown]
# ## Extra Tree Classifier (et)

# %%
#interpret_model(et plot = 'summary')

# %%
#interpret_model(et, plot='correlation', feature='avgCreditScore')

# %% [markdown]
# # Predict models using the "Oversampled" test holdout within PyCaret

# %% [markdown]
# #### CatBoost

# %%
pred_holdout = predict_model(catboost)
# Out:
#                  Model  Accuracy     AUC  Recall  Prec.      F1  Kappa
# 0  CatBoost Classifier     0.777  0.8541  0.8304   0.75  0.7882  0.554

# %% [markdown]
# #### Tuned CatBoost

# %%
pred_holdout_tuned = predict_model(tuned_catboost)
# Out:
#                  Model  Accuracy     AUC  Recall   Prec.      F1  Kappa
# 0  CatBoost Classifier    0.8645  0.9336  0.9286  0.8229  0.8726  0.729

# %% [markdown]
# #### Light GBM

# %%
pred_holdout = predict_model(lightgbm)
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine     0.751  0.8261   0.806  0.7259  0.7638
#
#     Kappa
# 0  0.5021

# %% [markdown]
# #### Tuned Light GBM

# %%
pred_holdout_tuned = predict_model(tuned_lightgbm)
# Out:
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.8757  0.9401  0.9397  0.8329  0.8831
#
#     Kappa
# 0  0.7515

# %% [markdown]
# # The golden moment... put 10% sample test data through the models...

# %% [markdown]
# # Recombine test_features, test_target at first train/test/split
#  This "test" set was split BEFORE Oversampling. PyCaret takes the "train" from this split and splits it internally again. Since we have no control of how PyCaret does this we needed to do a train/test split before we input the training set into PyCaret. Now we will recombine the test_features and test_target into one new df

# %%
test_features.shape
# Out:
# (11970, 30)

# %%
test_target.shape
# Out:
# (11970,)

# %%
test_df = test_features.copy()

# %%
test_df['zeroBalCode'] = test_target

# %%
test_df.shape
# Out:
# (11970, 31)

# %%
totalTestCount = test_df.zeroBalCode.value_counts().sum()
posTestCount = test_df.zeroBalCode.value_counts()[1]
print('#############################################')
print('This "Test" set has not been oversamplied')
print(test_df.zeroBalCode.value_counts())
print(f'Positive samples are {round(posTestCount/totalTestCount*100,2)}%')
# Out:
# #############################################
# This "Test" set has not been oversamplied
# 0    10307
# 1     1663
# Name: zeroBalCode, dtype: int64
# Positive samples are 13.89%

# %% [markdown]
# # Tuned Catboost

# %%
predictions = predict_model(tuned_catboost, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#    origChannel  origIntRate  origUPB  origLTV  numBorrowers  origDebtIncRatio  \
# 0            3        4.990   173000       70             1                37
# 1            1        5.625   122000       70             1                21
# 2            2        4.875   188000       70             2                52
# 3            1        3.750   262000       70             1                21
# 4            2        3.625   259000       80             1                45
#
#    borrCreditScore  loanPurp  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0              663         2      972       0.0            0              663
# 1              650         1      170       0.0            0              650
# 2              772         1      837       0.0            0              772
# 3              775         1      900       0.0            0              775
# 4              732         2      500       0.0            0              732
#
#    worstCreditScore  avgCreditScore  bankNumber  stateNumber    mSA  \
# 0               663             663          27           38  38900
# 1               650             650          80           39  30140
# 2               742             757           3           14  14260
# 3               775             775          54            4  31080
# 4               732             732          53           13  19780
#
#    fmacRateMax  fmacRateMin  fmacRateAvg  fmacRateVolatility  fredRate  \
# 0         4.91         4.78       4.8400            0.027197      3.46
# 1         5.25         5.04       5.1300            0.041667      2.87
# 2         5.59         5.29       5.4200            0.056711      3.71
# 3         3.56         3.51       3.5325            0.014245      2.04
# 4         3.62         3.49       3.5500            0.037249      1.67
#
#    rateDiffAbove  rateDiffBelow  rateDiffAvg  rateDiffAbovePct  \
# 0          0.080         -0.210       0.1500          0.016293
# 1          0.375         -0.585       0.4950          0.071429
# 2         -0.715          0.415      -0.5450         -0.127907
# 3          0.190         -0.240       0.2175          0.053371
# 4          0.005         -0.135       0.0750          0.001381
#
#    rateDiffBelowPct  rateDiffAvgPct  origYear  origMonth  zeroBalCode  Label  \
# 0         -0.043933        0.030992      2011          4            0      0
# 1         -0.116071        0.096491      2009          2            0      1
# 2          0.078450       -0.100554      2009          6            0      0
# 3         -0.068376        0.061571      2013          2            0      0
# 4         -0.038682        0.021127      2012          7            0      0
#
#     Score
# 0  0.4209
# 1  0.6352
# 2  0.3166
# 3  0.2603
# 4  0.2361

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    8900
# 1    3070
# Name: Label, dtype: int64

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalseNegative'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalsePositive'
    else:
        value = 'Undefined'
    return value

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
print(f'           ##############################')
print(f'           #             #              #')
print(f'         0 #    {confusionMatrix["TrueNegative"]}     #     {confusionMatrix["FalsePositive"]}      #')
print(f'  True     #             #              #')
print(f'  Class    ##############################')
print(f'           #             #              #')
print(f'         1 #    {confusionMatrix["FalseNegative"]}      #     {confusionMatrix["TruePositive"]}     #')
print(f'           #             #              #')
print(f'           ##############################')
print(f'                  0              1        ')
print(f'                  Predicted Class           ')
# Out:
#            ##############################
#            #             #              #
#          0 #    8097     #     803      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    2210      #     860     #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
# 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
trueNegativePct = confusionMatrix['TrueNegative'] / totalNegative * 100
falseNegativePct = confusionMatrix['FalseNegative'] / totalNegative * 100
truePositivePct = confusionMatrix['TruePositive'] / totalPositive * 100
falsePositivePct = confusionMatrix['FalsePositive'] / totalPositive * 100

print(f'TrueNegative:  {round(trueNegativePct,2)}%')
print(f'FalseNegative:  {round(falseNegativePct,2)}%')
print(f'TruePosiive:   {round(truePositivePct,2)}%')
print(f'FalsePositive: {round(falsePositivePct,2)}%')
# Out:
# TrueNegative:  78.56%
# FalseNegative:  21.44%
# TruePosiive:   51.71%
# FalsePositive: 48.29%

# %% [markdown]
# #### Well this is disappointing... The non-oversampled test dataset performed worse than random flipping a coin!

# %%
save_model(tuned_catboost, 'tunedCatboost_EPOCH2_Over50_50_052520')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# # Tuned Light GBM Fold = 10

# %%
predictions = predict_model(tuned_lightgbm, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#    origChannel  origIntRate  origUPB  origLTV  numBorrowers  origDebtIncRatio  \
# 0            3        4.990   173000       70             1                37
# 1            1        5.625   122000       70             1                21
# 2            2        4.875   188000       70             2                52
# 3            1        3.750   262000       70             1                21
# 4            2        3.625   259000       80             1                45
#
#    borrCreditScore  loanPurp  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0              663         2      972       0.0            0              663
# 1              650         1      170       0.0            0              650
# 2              772         1      837       0.0            0              772
# 3              775         1      900       0.0            0              775
# 4              732         2      500       0.0            0              732
#
#    worstCreditScore  avgCreditScore  bankNumber  stateNumber    mSA  \
# 0               663             663          27           38  38900
# 1               650             650          80           39  30140
# 2               742             757           3           14  14260
# 3               775             775          54            4  31080
# 4               732             732          53           13  19780
#
#    fmacRateMax  fmacRateMin  fmacRateAvg  fmacRateVolatility  fredRate  \
# 0         4.91         4.78       4.8400            0.027197      3.46
# 1         5.25         5.04       5.1300            0.041667      2.87
# 2         5.59         5.29       5.4200            0.056711      3.71
# 3         3.56         3.51       3.5325            0.014245      2.04
# 4         3.62         3.49       3.5500            0.037249      1.67
#
#    rateDiffAbove  rateDiffBelow  rateDiffAvg  rateDiffAbovePct  \
# 0          0.080         -0.210       0.1500          0.016293
# 1          0.375         -0.585       0.4950          0.071429
# 2         -0.715          0.415      -0.5450         -0.127907
# 3          0.190         -0.240       0.2175          0.053371
# 4          0.005         -0.135       0.0750          0.001381
#
#    rateDiffBelowPct  rateDiffAvgPct  origYear  origMonth  zeroBalCode  Label  \
# 0         -0.043933        0.030992      2011          4            0      0
# 1         -0.116071        0.096491      2009          2            0      1
# 2          0.078450       -0.100554      2009          6            0      1
# 3         -0.068376        0.061571      2013          2            0      0
# 4         -0.038682        0.021127      2012          7            0      0
#
#     Score
# 0  0.4960
# 1  0.8841
# 2  0.5111
# 3  0.1210
# 4  0.1902

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    8908
# 1    3062
# Name: Label, dtype: int64

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalseNegative'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalsePositive'
    else:
        value = 'Undefined'
    return value

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
print(f'           ##############################')
print(f'           #             #              #')
print(f'         0 #    {confusionMatrix["TrueNegative"]}     #     {confusionMatrix["FalsePositive"]}      #')
print(f'  True     #             #              #')
print(f'  Class    ##############################')
print(f'           #             #              #')
print(f'         1 #    {confusionMatrix["FalseNegative"]}     #     {confusionMatrix["TruePositive"]}      #')
print(f'           #             #              #')
print(f'           ##############################')
print(f'                  0              1        ')
print(f'                  Predicted Class           ')
# Out:
#            ##############################
#            #             #              #
#          0 #    8046     #     862      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    2261     #     801      #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
# 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
trueNegativePct = confusionMatrix['TrueNegative'] / totalNegative * 100
falseNegativePct = confusionMatrix['FalseNegative'] / totalNegative * 100
truePositivePct = confusionMatrix['TruePositive'] / totalPositive * 100
falsePositivePct = confusionMatrix['FalsePositive'] / totalPositive * 100

print(f'TrueNegative:  {round(trueNegativePct,2)}%')
print(f'FalseNegative:  {round(falseNegativePct,2)}%')
print(f'TruePosiive:   {round(truePositivePct,2)}%')
print(f'FalsePositive: {round(falsePositivePct,2)}%')
# Out:
# TrueNegative:  78.06%
# FalseNegative:  21.94%
# TruePosiive:   48.17%
# FalsePositive: 51.83%

# %% [markdown]
# #### Well this is disappointing... The non-oversampled test dataset performed worse than random flipping a coin!

# %%
#save_model(tuned_lightgbm, 'tunedLGBM_EPOCH2_Over50_50_052520')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# # Tuned Light GBM Fold = 100

# %%
predictions = predict_model(tuned_lightgbm100, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#    origChannel  origIntRate  origUPB  origLTV  numBorrowers  origDebtIncRatio  \
# 0            3        4.990   173000       70             1                37
# 1            1        5.625   122000       70             1                21
# 2            2        4.875   188000       70             2                52
# 3            1        3.750   262000       70             1                21
# 4            2        3.625   259000       80             1                45
#
#    borrCreditScore  loanPurp  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0              663         2      972       0.0            0              663
# 1              650         1      170       0.0            0              650
# 2              772         1      837       0.0            0              772
# 3              775         1      900       0.0            0              775
# 4              732         2      500       0.0            0              732
#
#    worstCreditScore  avgCreditScore  bankNumber  stateNumber    mSA  \
# 0               663             663          27           38  38900
# 1               650             650          80           39  30140
# 2               742             757           3           14  14260
# 3               775             775          54            4  31080
# 4               732             732          53           13  19780
#
#    fmacRateMax  fmacRateMin  fmacRateAvg  fmacRateVolatility  fredRate  \
# 0         4.91         4.78       4.8400            0.027197      3.46
# 1         5.25         5.04       5.1300            0.041667      2.87
# 2         5.59         5.29       5.4200            0.056711      3.71
# 3         3.56         3.51       3.5325            0.014245      2.04
# 4         3.62         3.49       3.5500            0.037249      1.67
#
#    rateDiffAbove  rateDiffBelow  rateDiffAvg  rateDiffAbovePct  \
# 0          0.080         -0.210       0.1500          0.016293
# 1          0.375         -0.585       0.4950          0.071429
# 2         -0.715          0.415      -0.5450         -0.127907
# 3          0.190         -0.240       0.2175          0.053371
# 4          0.005         -0.135       0.0750          0.001381
#
#    rateDiffBelowPct  rateDiffAvgPct  origYear  origMonth  zeroBalCode  Label  \
# 0         -0.043933        0.030992      2011          4            0      0
# 1         -0.116071        0.096491      2009          2            0      1
# 2          0.078450       -0.100554      2009          6            0      1
# 3         -0.068376        0.061571      2013          2            0      0
# 4         -0.038682        0.021127      2012          7            0      0
#
#     Score
# 0  0.4960
# 1  0.8841
# 2  0.5111
# 3  0.1210
# 4  0.1902

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    8908
# 1    3062
# Name: Label, dtype: int64

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalseNegative'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalsePositive'
    else:
        value = 'Undefined'
    return value

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
print(f'           ##############################')
print(f'           #             #              #')
print(f'         0 #    {confusionMatrix["TrueNegative"]}     #     {confusionMatrix["FalsePositive"]}      #')
print(f'  True     #             #              #')
print(f'  Class    ##############################')
print(f'           #             #              #')
print(f'         1 #    {confusionMatrix["FalseNegative"]}     #     {confusionMatrix["TruePositive"]}      #')
print(f'           #             #              #')
print(f'           ##############################')
print(f'                  0              1        ')
print(f'                  Predicted Class           ')
# Out:
#            ##############################
#            #             #              #
#          0 #    8046     #     862      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    2261     #     801      #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
# 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
trueNegativePct = confusionMatrix['TrueNegative'] / totalNegative * 100
falseNegativePct = confusionMatrix['FalseNegative'] / totalNegative * 100
truePositivePct = confusionMatrix['TruePositive'] / totalPositive * 100
falsePositivePct = confusionMatrix['FalsePositive'] / totalPositive * 100

print(f'TrueNegative:  {round(trueNegativePct,2)}%')
print(f'FalseNegative:  {round(falseNegativePct,2)}%')
print(f'TruePosiive:   {round(truePositivePct,2)}%')
print(f'FalsePositive: {round(falsePositivePct,2)}%')
# Out:
# TrueNegative:  78.06%
# FalseNegative:  21.94%
# TruePosiive:   48.17%
# FalsePositive: 51.83%

# %% [markdown]
# #### Well this is disappointing... The non-oversampled test dataset performed worse than random flipping a coin!

# %%
save_model(tuned_lightgbm100, 'tuned100LGBM_EPOCH2_Over50_50_052520')
# Out:
# Transformation Pipeline and Model Succesfully Saved
