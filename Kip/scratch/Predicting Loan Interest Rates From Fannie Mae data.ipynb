# %% [markdown]
# # Predicting 30 yr Mortgage Loan Interest Rates based on Fico scores
# ### Single Family, Refiance only

# %% [markdown]
# ### Introduction

# %% [markdown]
# **Step 1**:
# Clean and prepare the data.
#
# **Step 2**:
# Build several machine learning models in Python to predict the "quality" of interest rates
# you can expect given your Fico Score. Categories are "Worst","Bad","Par","Good","Best". The interest rate obtained is compared to the 30yr Freddie Mac rate for the week of the origination of the loan and then binned based % above or below the benchmark rate.
# Train the model on the training data, and run the model on the
# testing data.
#
# **Step 3**:
# Score the model by different metrics.

# %% [markdown]
# ## Import Dependencies

# %%
# import necessary python modules for analysis
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.metrics import mean_squared_error
import seaborn as sns
import pandas_profiling as pp

# %% [markdown]
# ## Step 1: Import, clean and prepare the data:
#
# Let's first import the data

# %%
# import Fannie19Q1ing_data via pandas module
Fannie19Q1 = pd.read_csv("data/Acquisition/Fannie19Q1_refi_avgfico.csv", low_memory=False)

# %%
Fannie19Q1['origDate'] = pd.to_datetime(Fannie19Q1['origDate'])

# %%
Fannie19Q1.shape
# Out:
# (28939, 19)

# %%
Fannie19Q1.head()
# Out:
#                                           sellerName  origChannel  \
# 0  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 1  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 2                                              OTHER            1
# 3                                 QUICKEN LOANS INC.            1
# 4                             WELLS FARGO BANK, N.A.            2
#
#    origIntRate  origUPB   origDate firstPmtDate  origLTV  origCLTV  \
# 0        4.625   160000 2019-02-01     4/1/2019       80        80
# 1        4.500   510000 2019-02-01     4/1/2019       64        64
# 2        4.750   256000 2019-01-01     3/1/2019       63        63
# 3        5.500    60000 2019-01-01     3/1/2019       25        25
# 4        4.625   175000 2019-01-01     3/1/2019       72        72
#
#    numBorrowers  origDebtIncRatio  borrCreditScore  BestCreditScore  \
# 0             2                34              758              758
# 1             2                40              772              772
# 2             1                47              786              786
# 3             1                45              766              766
# 4             2                47              704              730
#
#    WorstCreditScore  AvgCreditScore loanPurp propState  zipCode  pMIperct  \
# 0               752           755.0        C        IN      462         0
# 1               767           769.5        C        CA      913         0
# 2               786           786.0        C        CA      917         0
# 3               766           766.0        C        FL      339         0
# 4               704           717.0        C        SC      296         0
#
#    mortInsType
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
corr = Fannie19Q1.corr()

# %%
# Plot the Pearson Correlation reduced matrix
matrix = np.triu(corr)
fig, ax = plt.subplots(figsize=(15,9)) 
ax = sns.heatmap(corr,   mask = matrix, cmap = 'RdYlBu')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Pearson Correlation matrix for Fannie 2019 Q1 avg Fico scores dataset')
# Out:
# Text(0.5, 1, 'Pearson Correlation matrix for Fannie 2019 Q1 avg Fico scores dataset')

# %%
Fannie19Q1.head()
# Out:
#                                           sellerName  origChannel  \
# 0  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 1  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 2                                              OTHER            1
# 3                                 QUICKEN LOANS INC.            1
# 4                             WELLS FARGO BANK, N.A.            2
#
#    origIntRate  origUPB   origDate firstPmtDate  origLTV  origCLTV  \
# 0        4.625   160000 2019-02-01     4/1/2019       80        80
# 1        4.500   510000 2019-02-01     4/1/2019       64        64
# 2        4.750   256000 2019-01-01     3/1/2019       63        63
# 3        5.500    60000 2019-01-01     3/1/2019       25        25
# 4        4.625   175000 2019-01-01     3/1/2019       72        72
#
#    numBorrowers  origDebtIncRatio  borrCreditScore  BestCreditScore  \
# 0             2                34              758              758
# 1             2                40              772              772
# 2             1                47              786              786
# 3             1                45              766              766
# 4             2                47              704              730
#
#    WorstCreditScore  AvgCreditScore loanPurp propState  zipCode  pMIperct  \
# 0               752           755.0        C        IN      462         0
# 1               767           769.5        C        CA      913         0
# 2               786           786.0        C        CA      917         0
# 3               766           766.0        C        FL      339         0
# 4               704           717.0        C        SC      296         0
#
#    mortInsType
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# ## Get Freddie Mac 30 yr weekly rate

# %%
# import training_data via pandas module
fmac30 = pd.read_csv("data/FMAC-30US.csv", low_memory=False)

# %%
fmac30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2565 entries, 0 to 2564
# Data columns (total 2 columns):
# Date     2565 non-null object
# Value    2565 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 40.2+ KB

# %%
fmac30.head()
# Out:
#         Date  Value
# 0   4/2/1971   7.33
# 1   4/9/1971   7.31
# 2  4/16/1971   7.31
# 3  4/23/1971   7.31
# 4  4/30/1971   7.29

# %%
fmac30['Date'] = pd.to_datetime(fmac30['Date'])

# %%
fmac30 = fmac30[(fmac30['Date'] > '12/28/1999') & (fmac30['Date'] < '4/1/2019')]

# %%
fmac30.head()
# Out:
#            Date  Value
# 1500 1999-12-31   8.06
# 1501 2000-01-07   8.15
# 1502 2000-01-14   8.18
# 1503 2000-01-21   8.26
# 1504 2000-01-28   8.25

# %%
fmac30 = fmac30.set_index('Date').resample('D').ffill().reset_index()

# %%
fmac30 = fmac30.rename(columns={'Date':'origDate','Value':'fmacRate'})

# %%
fmac30.head()
# Out:
#     origDate  fmacRate
# 0 1999-12-31      8.06
# 1 2000-01-01      8.06
# 2 2000-01-02      8.06
# 3 2000-01-03      8.06
# 4 2000-01-04      8.06

# %% [markdown]
# ## Get 10 yr Treasury daily rate

# %%
# import training_data via pandas module
fred10 = pd.read_csv("data/FRED-DGS10.csv", low_memory=False)

# %%
fred10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14575 entries, 0 to 14574
# Data columns (total 2 columns):
# Date     14575 non-null object
# Value    14575 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 227.8+ KB

# %%
fred10.head()
# Out:
#        Date  Value
# 0  1/2/1962   4.06
# 1  1/3/1962   4.03
# 2  1/4/1962   3.99
# 3  1/5/1962   4.02
# 4  1/8/1962   4.03

# %%
fred10['Date'] = pd.to_datetime(fred10['Date'])

# %%
fred10 = fred10[(fred10['Date'] > '12/28/1999') & (fred10['Date'] < '4/1/2019')]

# %%
fred10 = fred10.set_index('Date').resample('D').ffill().reset_index()

# %%
fred10 = fred10.rename(columns={'Date':'origDate','Value':'fredRate'})

# %%
fred10.head()
# Out:
#     origDate  fredRate
# 0 1999-12-29      6.40
# 1 1999-12-30      6.39
# 2 1999-12-31      6.45
# 3 2000-01-01      6.45
# 4 2000-01-02      6.45

# %% [markdown]
# ## Merge data

# %%
# Merge data
merged = pd.merge(Fannie19Q1, fmac30, on=["origDate"])
merged.shape
# Out:
# (28939, 20)

# %%
# Merge data
merged = pd.merge(merged, fred10, on=["origDate"])
merged.shape
# Out:
# (28939, 21)

# %%
merged['rateDiff'] = merged['origIntRate'] - merged['fmacRate']

# %%
merged['rateDiffPct'] = merged['rateDiff'] / merged['fmacRate']

# %%
merged.shape
# Out:
# (28939, 23)

# %%
merged.head()
# Out:
#                                           sellerName  origChannel  \
# 0  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 1  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 2                                 QUICKEN LOANS INC.            0
# 3  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 4                                     PENNYMAC CORP.            2
#
#    origIntRate  origUPB   origDate firstPmtDate  origLTV  origCLTV  \
# 0        4.625   160000 2019-02-01     4/1/2019       80        80
# 1        4.500   510000 2019-02-01     4/1/2019       64        64
# 2        4.750   143000 2019-02-01     4/1/2019       68        68
# 3        4.500   160000 2019-02-01     4/1/2019       17        17
# 4        4.500   320000 2019-02-01     4/1/2019       74        74
#
#    numBorrowers  origDebtIncRatio  ...  AvgCreditScore  loanPurp  propState  \
# 0             2                34  ...           755.0         C         IN
# 1             2                40  ...           769.5         C         CA
# 2             1                16  ...           674.0         C         NC
# 3             1                43  ...           738.0         C         CA
# 4             2                26  ...           729.0         R         LA
#
#    zipCode pMIperct mortInsType  fmacRate  fredRate  rateDiff  rateDiffPct
# 0      462        0           0      4.46       2.7     0.165     0.036996
# 1      913        0           0      4.46       2.7     0.040     0.008969
# 2      286        0           0      4.46       2.7     0.290     0.065022
# 3      920        0           0      4.46       2.7     0.040     0.008969
# 4      707        0           0      4.46       2.7     0.040     0.008969
#
# [5 rows x 23 columns]

# %%
# Save the data prior to the binning steps
merged.to_csv('data/FannieAcq2019Q1FMac30.csv')

# %% [markdown]
# ## Create Classes for the rateDiffPct field
# #### rateDiffPct is the difference between the origination Interest Rate for the loan and the Freddie Mac 30 year Mortgage rate for the week of the origination of the loan. We want to bin rates by what % the differed from the published FMAC rate.

# %%
merged['rateDiffPct'].hist(bins=5)

# %%
bin_width = (merged['rateDiffPct'].max() - merged['rateDiffPct'].min())/5

# %%
bin_width
# Out:
# 0.1452471295520623

# %%
merged['rateDiffPct'].describe()
# Out:
# count    28939.000000
# mean         0.090866
# std          0.094903
# min         -0.215247
# 25%          0.034483
# 50%          0.071429
# 75%          0.126374
# max          0.510989
# Name: rateDiffPct, dtype: float64

# %%
merged['rateDiffPct'].value_counts(bins=7, sort=False)
# Out:
# (-0.217, -0.111]        105
# (-0.111, -0.00775]     3923
# (-0.00775, 0.096]     13456
# (0.096, 0.2]           7225
# (0.2, 0.303]           3325
# (0.303, 0.407]          820
# (0.407, 0.511]           85
# Name: rateDiffPct, dtype: int64

# %%
merged['rank'] = pd.cut(merged['rateDiffPct'], 9, labels=[0,1,2,3,4,5,6,7,8])

# %%
merged['rank'] = pd.to_numeric(merged['rank'])

# %%
merged['rank'].value_counts()
# Out:
# 3    12233
# 2     6189
# 4     5459
# 5     2697
# 6     1233
# 1      780
# 7      262
# 0       46
# 8       40
# Name: rank, dtype: int64

# %%
merged['rank'].plot(kind='hist')

# %%
merged.head()
# Out:
#                                           sellerName  origChannel  \
# 0  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 1  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 2                                 QUICKEN LOANS INC.            0
# 3  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...            1
# 4                                     PENNYMAC CORP.            2
#
#    origIntRate  origUPB   origDate firstPmtDate  origLTV  origCLTV  \
# 0        4.625   160000 2019-02-01     4/1/2019       80        80
# 1        4.500   510000 2019-02-01     4/1/2019       64        64
# 2        4.750   143000 2019-02-01     4/1/2019       68        68
# 3        4.500   160000 2019-02-01     4/1/2019       17        17
# 4        4.500   320000 2019-02-01     4/1/2019       74        74
#
#    numBorrowers  origDebtIncRatio  ...  loanPurp  propState  zipCode  \
# 0             2                34  ...         C         IN      462
# 1             2                40  ...         C         CA      913
# 2             1                16  ...         C         NC      286
# 3             1                43  ...         C         CA      920
# 4             2                26  ...         R         LA      707
#
#    pMIperct mortInsType fmacRate  fredRate  rateDiff  rateDiffPct  rank
# 0         0           0     4.46       2.7     0.165     0.036996     3
# 1         0           0     4.46       2.7     0.040     0.008969     2
# 2         0           0     4.46       2.7     0.290     0.065022     3
# 3         0           0     4.46       2.7     0.040     0.008969     2
# 4         0           0     4.46       2.7     0.040     0.008969     2
#
# [5 rows x 24 columns]

# %%
#merged.to_csv('data/FannieAcq2019Q1FMac30bin9.csv')

# %%
pp.ProfileReport(merged)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>28939 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>5.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>200.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_AvgCreditScore"><code>AvgCreditScore</code></a> is highly correlated with <a href="#pp_var_WorstCreditScore"><code>WorstCreditScore</code></a> (ρ = 0.97439) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_BestCreditScore"><code>BestCreditScore</code></a> is highly correlated with <a href="#pp_var_borrCreditScore"><code>borrCreditScore</code></a> (ρ = 0.93637) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_WorstCreditScore"><code>WorstCreditScore</code></a> is highly correlated with <a href="#pp_var_borrCreditScore"><code>borrCreditScore</code></a> (ρ = 0.94883) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_mortInsType"><code>mortInsType</code></a> has 26322 / 91.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_origCLTV"><code>origCLTV</code></a> is highly correlated with <a href="#pp_var_origLTV"><code>origLTV</code></a> (ρ = 0.98905) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_origChannel"><code>origChannel</code></a> has 17615 / 60.9% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_pMIperct"><code>pMIperct</code></a> has
