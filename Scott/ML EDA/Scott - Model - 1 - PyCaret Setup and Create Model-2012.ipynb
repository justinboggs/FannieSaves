# %% [markdown]
# # Goal: predict whether a loan will end up with maximum profits or not
#
# ---
# #### Target variable: `outcome`
# * Type: **Categorical**
# * Model type: Classification
# * Sourced from: `zeroBalCode`
# * Data:
#     - "0" means "Closed" (i.e. a successful outcome for Fannie Mae)
#     - "1" means "Default" (i.e. a negative outcome)
#
# ---
# #### This Notebook:
# * Input required: The output files from "Scott - Data Pre - 2 - 50 50 split train test" notebook
#     - ../data/DataPre-2-5050-split-2011-test.csv
# * Outputs generated: Decision on what model to use
#
# #### Expected Workflow
# 1. Scott - Data Pre - 1 - Feature EEE
# 2. Scott - Data Pre - 2 - 50 50 split train test
# 3. Scott - Model - 1- PyCaret Setup and Create Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *
#!pip install pycaret

from sklearn.feature_selection import VarianceThreshold

import winsound

# Tell Jupyter to display all text, not just "the last" and print()
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %pwd

def DoneNotice(duration_ms = 1000):
    duration = duration_ms  # milliseconds
    freq = 440  #Hz
    winsound.Beep(freq, duration)

from IPython.display import Markdown, display
def Important(html_tag, message, color):
    colorstr = f"<{html_tag} style='color:{color}'>{message}</{html_tag}>"
    display(Markdown(colorstr))
# Out:
# 'C:\\Users\\Scott\\Desktop\\Project3_2\\Scott\\ML EDA'

# %% [markdown]
# # Importing the data

# %%
df = pd.read_csv("../data/DataPre-2-5050-split-2011-test.csv")

# Remove the weird unnamed column
df.drop(['Unnamed: 0'], 1, inplace=True)

print(df.shape)

df.sample(5)
# Out:
# (17228, 12)
#        origChannel  origIntRate  origUPB  origLTV  numBorrowers  \
# 14827            3        4.375   134000       80             1
# 2551             1        5.250   138000       70             1
# 16123            1        5.000   146000       78             2
# 10907            1        6.375   141000       80             1
# 9805             3        4.875   275000       74             1
#
#        origDebtIncRatio  loanPurp  worstCreditScore  bankNumber  stateNumber  \
# 14827                39         2               684          54           10
# 2551                 40         1               652           4           46
# 16123                22         2               642          80           36
# 10907                36         1               625           4           39
# 9805                 41         2               682          32           13
#
#          mSA  zeroBalCode
# 14827      0            1
# 2551   41620            0
# 16123      0            1
# 10907  37980            1
# 9805   19780            0

# %% [markdown]
# # Pycaret - Setup with categorical definition
#
# #### Normalization
# https://pycaret.org/normalization/
#
# > `normalize: bool, default = False` - When set to True, the feature space is transformed using the normalized_method param. **Generally, linear algorithms perform better with normalized data** however, the results may vary and it is advised to run multiple experiments to evaluate the benefit of normalization.

# %%
# %%time

model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , pca = False 
    # , ignore_low_variance = True # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value.
    , normalize = True
    , ignore_features = None
    # , remove_outliers = True # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
    , silent = True
    , profile = False
    , categorical_features = [
            'origChannel'
            , 'loanPurp'
            , 'bankNumber'
            , 'stateNumber'
            , 'mSA'
        ]
    , numeric_features = [
        'origIntRate'
        , 'origUPB'
        , 'origLTV'
        , 'numBorrowers'
        , 'origDebtIncRatio'
        , 'worstCreditScore'
    ]
)

DoneNotice(2000)

Important("h1", "PyCaret setup completed", 'blue')

# session_id - if you ever want to reprint the results later, pass the session_id to setup()
#      and it will run the setup using the same split of test/train
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_e95291be_9f7a_11ea_9894_6c0b84b3712brow15_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_e95291be_9f7a_11ea_9894_6c0b84b3712b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow0_col1" class="data row0 col1" >4660</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow3_col1" class="data row3 col1" >(17228, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow5_col1" class="data row5 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow6_col1" class="data row6 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow10_col1" class="data row10 col1" >(17228, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow11_col1" class="data row11 col1" >(12059, 478)</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow12_col1" class="data row12 col1" >(5169, 478)</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e95291be_9f7a_11ea_9894_6c0b84b3712blevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_e95291be_9f7a_11ea_9894_6c0b84b3712brow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td
# <h1 style='color:blue'>PyCaret setup completed</h1>
# Wall time: 3.02 s

# %% [markdown]
# # Decide which model to use

# %%
model_results=compare_models(
    fold=10
    , blacklist = None
    ,  round = 4 # number of decimal places to round to. 4 is default
    ,  sort = 'Recall'
    , turbo = True # True by default. Auto blacklists models that have longer training times. When True, rbfsvm, gpc and mlp are excluded due to longer training times. If you set to False, could take a long time
)
model_results
# Out:
# <style  type="text/css" >
#     #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712b th {
#           text-align: left;
#     }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow5_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow10_col0 {
#             text-align:  left;
#         }    #T_b34f3eb4_9e05_11ea_8ec5_6c0b84b3712brow10

# %% [markdown]
# # Results
# Full test set: Extra Trees Classifier

# %%
# %%time
# Can influence performance by reducing # of folds (10 is def.) or adding blacklists/exclusions
# Regression has about 21 models
# Classification has about 15 models
# Logistic Regression - ‘lr’
# K Nearest Neighbour - ‘knn’
# Naives Bayes - ‘nb’
# Decision Tree - ‘dt’
# SVM (Linear) - ‘svm’
# Gaussian Process - ‘gpc’
# Ridge Classifier - ‘ridge’
# Random Forest - ‘rf’
# Quadratic Disc. Analysis - ‘qda’
# AdaBoost - ‘ada’
# Linear Disc. Analysis - ‘lda’
# Extra Trees Classifier - ‘et’
# Extreme Gradient Boosting - ‘xgboost’
# Light Gradient Boosting - ‘lightgbm’
# Cat Boost Classifier - ‘catboost’
####### Off by default (enable w "turbo = False")
# Multi Level Perceptron - ‘mlp’
# Gradient Boosting Classifier - ‘gbc’
# SVM (RBF) - ‘rbfsvm’
# 
# compare_models(blacklist=['catboost', 'xgboost', 'lightgbm'])
# 
# Slow: 
#    - Gaussian Process Classifier
#    - 

model_results=compare_models(
    fold=10
    , blacklist = [
            'nb'
            , 'knn'
            , 'svm'
            , 'qda'
            , 'rf'
            , 'lda'
            , 'ridge'
        ] 
    ,  round = 4 # number of decimal places to round to. 4 is default
    ,  sort = 'Recall'
    , turbo = True # True by default. Auto blacklists models that have longer training times. When True, rbfsvm, gpc and mlp are excluded due to longer training times. If you set to False, could take a long time
)
model_results

DoneNotice(2000)
# Out:
# IntProgress(value=0, description='Processing: ')
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:02:45
# Status     . . . . . . . . . . . . . . . . . .    Fitting Fold 7 of 10
# Estimator  . . . . . . . . . . . . . . . . . .     CatBoost Classifier
# ETC        . . . . . . . . . . . . . . . . . .  1.33 Minutes Remaining
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0         Decision Tree Classifier    0.9070  0.9069  0.9930  0.8473  0.9144
# 1           Extra Trees Classifier    0.9797  0.9970  0.9889  0.9710  0.9799
# 2  Light Gradient Boosting Machine    0.8316  0.9066  0.9065  0.7888  0.8434
# 3        Extreme Gradient Boosting    0.7439  0.8152  0.8065  0.7172  0.7591
# 4     Gradient Boosting Classifier    0.7448  0.8183  0.8056  0.7186  0.7595
# 5              Logistic Regression    0.7372  0.8085  0.7773  0.7199  0.7474
# 6             Ada Boost Classifier    0.7109  0.7837  0.7365  0.7010  0.7182
#
#     Kappa
# 0  0.8139
# 1  0.9594
# 2  0.6631
# 3  0.4878
# 4  0.4897
# 5  0.4744
# 6  0.4218
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# D:\Anaconda3\lib\site-packages\pycaret\classification.py in compare_models(blacklist, fold, round, sort, turbo)
#    3434             if hasattr(model, 'predict_proba'):
#    3435
# -> 3436                 model.fit(Xtrain,ytrain)
#    3437                 pred_prob = model.predict_proba(Xtest)
#    3438                 pred_prob = pred_prob[:,1]
#
# D:\Anaconda3\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, text_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    3791         self._fit(X, y, cat_features, text_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    3792                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 3793                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    3794         return self
#    3795
#
# D:\Anaconda3\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1688                 params,
#    1689                 allow_clear_pool,
# -> 1690                 train_params["init_model"]
#    1691             )
#    1692
#
# D:\Anaconda3\lib\site-packages\catboost\core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1223
#    1224     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1225         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1226         self._set_trained_model_attributes()
#    1227
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
# Extra Trees Classifier	 has best balance
et = create_model(
    'et'
    , ensemble = False
    , method = None # if ensemble, choose 'Bagging' or 'Boosting'
    , fold = 10
    , round = 4 # decimal places
    , verbose = True
)
# Out:
# IntProgress(value=0, description='Processing: ', max=14)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               22:00:45
# Status     . . . . . . . . . . . . . . . . . .      Waiting for input
# ETC        . . . . . . . . . . . . . . . . . .  0.0 Seconds Remaining
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa]
# Index: []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2ee598ef8d63> in <module>
#       6     'et'
#       7     , ensemble = True
# ----> 8     , method = 'Boosting'
#       9 )
#
# D:\Anaconda3\lib\site-packages\pycaret\classification.py in create_model(estimator, ensemble, method, fold, round, verbose)
#    1716
#    1717     #Storing X_train and y_train in data_X and data_y parameter
# -> 1718     data_X = X_train.copy()
#    1719     data_y = y_train.copy()
#    1720
#
# NameError: name 'X_train' is not defined
